# %% [markdown]
# # Flat Resale

# %% [markdown]
# ### Import the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/teresazhang/Documents/NTU/Y3S1/BC3409/Assignment/ResaleFlatPrice.csv")

# %% [markdown]
# ### Check for null values

# %%
df.isnull().any()
# Out:
# month                  False
# town                   False
# flat_type              False
# block                  False
# street_name            False
# storey_range           False
# floor_area_sqm         False
# flat_model             False
# lease_commence_date    False
# remaining_lease        False
# resale_price           False
# dtype: bool

# %%
df.describe()
# Out:
#        floor_area_sqm  lease_commence_date  resale_price
# count    22204.000000         22204.000000  2.220400e+04
# mean        97.075545          1994.459827  4.320591e+05
# std         24.356244            13.218726  1.539752e+05
# min         31.000000          1966.000000  1.500000e+05
# 25%         77.000000          1984.000000  3.200000e+05
# 50%         94.000000          1994.000000  4.000000e+05
# 75%        112.000000          2004.000000  5.100000e+05
# max        192.000000          2016.000000  1.205000e+06

# %% [markdown]
# ### Data Visualisation

# %%
df.boxplot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'floor_area_sqm'}>,
#         <AxesSubplot:title={'center':'lease_commence_date'}>],
#        [<AxesSubplot:title={'center':'resale_price'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
import seaborn as sns

# %%
df.corr()
# Out:
#                      floor_area_sqm  lease_commence_date  resale_price
# floor_area_sqm             1.000000             0.145923      0.634752
# lease_commence_date        0.145923             1.000000      0.315368
# resale_price               0.634752             0.315368      1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["resale_price"], df["floor_area_sqm"])
plt.xlabel("Resale Price")
plt.ylabel("Floor Area")
plt.title("Resale Price vs Floor Area")
# Out:
# Text(0.5, 1.0, 'Resale Price vs Floor Area')

# %%
plt.scatter(df["resale_price"], df["lease_commence_date"])
plt.xlabel("Resale Price")
plt.ylabel("Lease Commence Date")
plt.title("Resale Price vs Lease Commence Date")
# Out:
# Text(0.5, 1.0, 'Resale Price vs Lease Commence Date')

# %% [markdown]
# ### Use the attributes decided for X

# %%
df_drop = df[["resale_price","town", "flat_type", "floor_area_sqm", "flat_model", "lease_commence_date"]]

# %%
df_drop
# Out:
#        resale_price        town  flat_type  floor_area_sqm      flat_model  \
# 0          270000.0  ANG MO KIO     3 ROOM            68.0  New Generation
# 1          295000.0  ANG MO KIO     3 ROOM            73.0  New Generation
# 2          270000.0  ANG MO KIO     3 ROOM            67.0  New Generation
# 3          230000.0  ANG MO KIO     3 ROOM            67.0  New Generation
# 4          262500.0  ANG MO KIO     3 ROOM            68.0  New Generation
# ...             ...         ...        ...             ...             ...
# 22199      580000.0      YISHUN  EXECUTIVE           142.0       Apartment
# 22200      565000.0      YISHUN  EXECUTIVE           146.0      Maisonette
# 22201      633000.0      YISHUN  EXECUTIVE           164.0       Apartment
# 22202      788888.0      YISHUN  EXECUTIVE           164.0       Apartment
# 22203      618000.0      YISHUN  EXECUTIVE           145.0      Maisonette
#
#        lease_commence_date
# 0                     1981
# 1                     1976
# 2                     1978
# 3                     1978
# 4                     1981
# ...                    ...
# 22199                 1988
# 22200                 1988
# 22201                 1992
# 22202                 1992
# 22203                 1987
#
# [22204 rows x 6 columns]

# %% [markdown]
# ### Creating dummy variables on categorical input

# %%
df_dc = pd.get_dummies(df_drop, columns=['town', 'flat_type', 'flat_model'])

# %% [markdown]
# ### Normalize floor_area_sqm using zscore

# %%
from scipy import stats

# %%
df_dc["floor_area_sqm"] = stats.zscore(df["floor_area_sqm"] )

# %% [markdown]
# ### Split into train test

# %%
X = df_dc.drop(columns=["resale_price"])
Y = df_dc["resale_price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=1)

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.metrics import mean_squared_error
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_test)
pred
# Out:
# array([417996.57479733, 368909.22684785, 306819.97027265, ...,
#        367756.95397033, 515145.14965147, 725937.87754341])

# %%
print("RMSE for linear regression:", mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for linear regression: 62455.43131423416

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### VIF - Check Collinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X_train.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X_train.values, i)
                          for i in range(len(X_train.columns))]
  
print(vif_data)
# Out:
# /Users/teresazhang/opt/anaconda3/lib/python3.8/site-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                               feature        VIF
# 0                      floor_area_sqm  22.867916
# 1                 lease_commence_date   3.304360
# 2                     town_ANG MO KIO        inf
# 3                          town_BEDOK        inf
# 4                         town_BISHAN        inf
# 5                    town_BUKIT BATOK        inf
# 6                    town_BUKIT MERAH        inf
# 7                  town_BUKIT PANJANG        inf
# 8                    town_BUKIT TIMAH        inf
# 9                   town_CENTRAL AREA        inf
# 10                 town_CHOA CHU KANG        inf
# 11                      town_CLEMENTI        inf
# 12                       town_GEYLANG        inf
# 13                       town_HOUGANG        inf
# 14                   town_JURONG EAST        inf
# 15                   town_JURONG WEST        inf
# 16               town_KALLANG/WHAMPOA        inf
# 17                 town_MARINE PARADE        inf
# 18                     town_PASIR RIS        inf
# 19                       town_PUNGGOL        inf
# 20                    town_QUEENSTOWN        inf
# 21                     town_SEMBAWANG        inf
# 22                      town_SENGKANG        inf
# 23                     town_SERANGOON        inf
# 24                      town_TAMPINES        inf
# 25                     town_TOA PAYOH        inf
# 26                     town_WOODLANDS        inf
# 27                        town_YISHUN        inf
# 28                   flat_type_1 ROOM        inf
# 29                   flat_type_2 ROOM        inf
# 30                   flat_type_3 ROOM        inf
# 31                   flat_type_4 ROOM        inf
# 32                   flat_type_5 ROOM        inf
# 33                flat_type_EXECUTIVE        inf
# 34         flat_type_MULTI-GENERATION        inf
# 35           flat_model_Adjoined flat        inf
# 36               flat_model_Apartment        inf
# 37                    flat_model_DBSS        inf
# 38                flat_model_Improved        inf
# 39     flat_model_Improved-Maisonette        inf
# 40              flat_model_Maisonette        inf
# 41                 flat_model_Model A        inf
# 42      flat_model_Model A-Maisonette        inf
# 43                flat_model_Model A2        inf
# 44        flat_model_Multi Generation        inf
# 45          flat_model_New Generation        inf
# 46       flat_model_Premium Apartment        inf
# 47  flat_model_Premium Apartment Loft        inf
# 48      flat_model_Premium Maisonette        inf
# 49              flat_model_Simplified        inf
# 50                flat_model_Standard        inf
# 51                 flat_model_Terrace        inf
# 52                 flat_model_Type S1        inf
# 53                 flat_model_Type S2        inf

# %% [markdown]
# #### QQ plot - Check Heteroskedasticity

# %%
import statsmodels.api as sm 
from matplotlib import pyplot as plt
mod_fit = sm.OLS(Y_train, X_train).fit()
res = mod_fit.resid
fig = sm.qqplot(res)
plt.show()

# %% [markdown]
# The graph is slightly skewed to the right, suggesting that the errors do not that a constant variance

# %% [markdown]
# #### Anova - Check Significant

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
model = ols("Y~X", df_dc).fit()
print(model.summary())
anova_results = anova_lm(model)
print("\nANOVA results")
print(anova_results)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.841
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     2346.
# Date:                Sun, 09 Oct 2022   Prob (F-statistic):               0.00
# Time:                        17:12:39   Log-Likelihood:            -2.7630e+05
# No. Observations:               22204   AIC:                         5.527e+05
# Df Residuals:                   22153   BIC:                         5.531e+05
# Df Model:                          50
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -8.129e+06   9.09e+04    -89.399      0.000   -8.31e+06   -7.95e+06
# X[0]         8.14e+04   1942.584     41.904      0.000    7.76e+04    8.52e+04
# X[1]        5327.3307     56.523     94.250      0.000    5216.541    5438.120
# X[2]       -2.972e+05   4038.191    -73.598      0.000   -3.05e+05   -2.89e+05
# X[3]       -3.022e+05   3827.229    -78.965      0.000    -3.1e+05   -2.95e+05
# X[4]       -1.914e+05   4524.456    -42.299      0.000      -2e+05   -1.83e+05
# X[5]       -3.834e+05   4003.512    -95.774      0.000   -3.91e+05   -3.76e+05
# X[6]       -1.644e+05   4089.121    -40.204      0.000   -1.72e+05   -1.56e+05
# X[7]        -4.24e+05   4278.783    -99.095      0.000   -4.32e+05   -4.16e+05
# X[8]       -7.736e+04   7763.931     -9.963      0.000   -9.26e+04   -6.21e+04
# X[9]       -1.566e+05   6033.706    -25.958      0.000   -1.68e+05   -1.45e+05
# X[10]      -4.765e+05   4182.154   -113.948      0.000   -4.85e+05   -4.68e+05
# X[11]      -2.505e+05   4462.857    -56.134      0.000   -2.59e+05   -2.42e+05
# X[12]      -2.466e+05   4269.509    -57.765      0.000   -2.55e+05   -2.38e+05
# X[13]      -3.759e+05   4100.389    -91.663      0.000   -3.84e+05   -3.68e+05
# X[14]      -3.621e+05   4423.316    -81.863      0.000   -3.71e+05   -3.53e+05
# X[15]      -4.344e+05   3838.221   -113.173      0.000   -4.42e+05   -4.27e+05
# X[16]      -2.169e+05   4170.867    -51.998      0.000   -2.25e+05   -2.09e+05
# X[17]      -1.355e+05   6230.273    -21.744      0.000   -1.48e+05   -1.23e+05
# X[18]      -3.953e+05   4481.639    -88.197      0.000   -4.04e+05   -3.86e+05
# X[19]      -4.098e+05   4525.069    -90.573      0.000   -4.19e+05   -4.01e+05
# X[20]      -1.537e+05   4358.254    -35.277      0.000   -1.62e+05   -1.45e+05
# X[21]      -4.882e+05   4533.810   -107.675      0.000   -4.97e+05   -4.79e+05
# X[22]      -4.273e+05   4296.673    -99.442      0.000   -4.36e+05   -4.19e+05
# X[23]      -2.903e+05   4518.027    -64.261      0.000   -2.99e+05   -2.81e+05
# X[24]      -3.405e+05   3827.618    -88.971      0.000   -3.48e+05   -3.33e+05
# X[25]       -2.36e+05   3937.504    -59.938      0.000   -2.44e+05   -2.28e+05
# X[26]      -4.683e+05   4055.467   -115.470      0.000   -4.76e+05    -4.6e+05
# X[27]      -4.242e+05   3978.574   -106.623      0.000   -4.32e+05   -4.16e+05
# X[28]      -1.317e+06   2.01e+04    -65.601      0.000   -1.36e+06   -1.28e+06
# X[29]      -1.266e+06   1.35e+04    -93.571      0.000   -1.29e+06   -1.24e+06
# X[30]      -1.233e+06   1.33e+04    -92.596      0.000   -1.26e+06   -1.21e+06
# X[31]      -1.207e+06   1.42e+04    -85.035      0.000   -1.23e+06   -1.18e+06
# X[32]      -1.174e+06   1.56e+04    -75.211      0.000    -1.2e+06   -1.14e+06
# X[33]      -1.171e+06   1.63e+04    -71.997      0.000    -1.2e+06   -1.14e+06
# X[34]      -7.604e+05    1.3e+04    -58.603      0.000   -7.86e+05   -7.35e+05
# X[35]      -4.604e+05   1.02e+04    -45.072      0.000    -4.8e+05    -4.4e+05
# X[36]      -4.737e+05   7402.473    -63.991      0.000   -4.88e+05   -4.59e+05
# X[37]      -3.461e+05   7287.819    -47.488      0.000    -3.6e+05   -3.32e+05
# X[38]      -5.147e+05   5492.057    -93.716      0.000   -5.25e+05   -5.04e+05
# X[39]      -3.081e+05   4.15e+04     -7.423      0.000   -3.89e+05   -2.27e+05
# X[40]      -4.435e+05   7392.303    -59.994      0.000   -4.58e+05   -4.29e+05
# X[41]      -5.083e+05   6163.530    -82.476      0.000    -5.2e+05   -4.96e+05
# X[42]      -4.119e+05   1.03e+04    -39.856      0.000   -4.32e+05   -3.92e+05
# X[43]      -5.101e+05   6942.260    -73.479      0.000   -5.24e+05   -4.97e+05
# X[44]      -7.604e+05    1.3e+04    -58.603      0.000   -7.86e+05   -7.35e+05
# X[45]      -4.964e+05   5583.890    -88.898      0.000   -5.07e+05   -4.85e+05
# X[46]      -5.006e+05   6081.698    -82.313      0.000   -5.13e+05   -4.89e+05
# X[47]       -2.84e+05   2.99e+04     -9.491      0.000   -3.43e+05   -2.25e+05
# X[48]      -4.634e+05   3.01e+04    -15.411      0.000   -5.22e+05   -4.05e+05
# X[49]      -4.971e+05   5830.533    -85.250      0.000   -5.08e+05   -4.86e+05
# X[50]      -5.087e+05   5470.850    -92.987      0.000   -5.19e+05   -4.98e+05
# X[51]      -1.561e+05   1.68e+04     -9.283      0.000   -1.89e+05   -1.23e+05
# X[52]      -2.594e+05   1.27e+04    -20.443      0.000   -2.84e+05   -2.35e+05
# X[53]      -2.257e+05   1.66e+04    -13.608      0.000   -2.58e+05   -1.93e+05
# ==============================================================================
# Omnibus:                     1953.354   Durbin-Watson:                   1.183
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3043.581
# Skew:                           0.672   Prob(JB):                         0.00
# Kurtosis:                       4.218   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.82e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# ANOVA results
#                df        sum_sq       mean_sq            F  PR(>F)
# X            54.0  4.427802e+14  8.199633e+12  2172.267841     0.0
# Residual  22153.0  8.362066e+13  3.774688e+09          NaN     NaN

# %% [markdown]
# ### Decision Tree

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor(random_state=1)

# %%
model.fit(X_train,Y_train)
pred = model.predict(X_test)
print("RMSE for decision tree:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for decision tree: 43711.16010257397

# %% [markdown]
# ### Model Analysis

# %% [markdown]
# #### Feature Ranking

# %%
from matplotlib import pyplot
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.40460
# Feature: 1, Score: 0.14853
# Feature: 2, Score: 0.00667
# Feature: 3, Score: 0.00309
# Feature: 4, Score: 0.03037
# Feature: 5, Score: 0.00570
# Feature: 6, Score: 0.05190
# Feature: 7, Score: 0.00264
# Feature: 8, Score: 0.00853
# Feature: 9, Score: 0.01991
# Feature: 10, Score: 0.00630
# Feature: 11, Score: 0.00999
# Feature: 12, Score: 0.00823
# Feature: 13, Score: 0.00149
# Feature: 14, Score: 0.00211
# Feature: 15, Score: 0.00781
# Feature: 16, Score: 0.01668
# Feature: 17, Score: 0.00610
# Feature: 18, Score: 0.00297
# Feature: 19, Score: 0.00208
# Feature: 20, Score: 0.04124
# Feature: 21, Score: 0.00709
# Feature: 22, Score: 0.01140
# Feature: 23, Score: 0.00365
# Feature: 24, Score: 0.00608
# Feature: 25, Score: 0.01138
# Feature: 26, Score: 0.01524
# Feature: 27, Score: 0.00657
# Feature: 28, Score: 0.00000
# Feature: 29, Score: 0.00682
# Feature: 30, Score: 0.00048
# Feature: 31, Score: 0.09642
# Feature: 32, Score: 0.00390
# Feature: 33, Score: 0.00006
# Feature: 34, Score: 0.00001
# Feature: 35, Score: 0.00029
# Feature: 36, Score: 0.00091
# Feature: 37, Score: 0.01707
# Feature: 38, Score: 0.00402
# Feature: 39, Score: 0.00000
# Feature: 40, Score: 0.00056
# Feature: 41, Score: 0.00381
# Feature: 42, Score: 0.00019
# Feature: 43, Score: 0.00014
# Feature: 44, Score: 0.00000
# Feature: 45, Score: 0.00071
# Feature: 46, Score: 0.01416
# Feature: 47, Score: 0.00000
# Feature: 48, Score: 0.00035
# Feature: 49, Score: 0.00031
# Feature: 50, Score: 0.00058
# Feature: 51, Score: 0.00088
# Feature: 52, Score: 0.00000
# Feature: 53, Score: 0.00000

# %% [markdown]
# #### Plot Tree

# %%
plt.subplots(figsize=(20, 10))
tree.plot_tree(model, fontsize=10)
# Out:
# [Text(0.4745844454487736, 0.9886363636363636, 'X[0] <= -0.516\nsquared_error = 23569257722.566\nsamples = 16653\nvalue = 431615.454'),
#  Text(0.1858059138077421, 0.9659090909090909, 'X[0] <= -0.927\nsquared_error = 5896297542.995\nsamples = 4955\nvalue = 301346.824'),
#  Text(0.13821109557530636, 0.9431818181818182, 'X[1] <= 2001.0\nsquared_error = 4484914417.716\nsamples = 4055\nvalue = 289104.63'),
#  Text(0.10567691933836074, 0.9204545454545454, 'X[9] <= 0.5\nsquared_error = 2410993207.961\nsamples = 3129\nvalue = 274584.34'),
#  Text(0.06939971976737665, 0.8977272727272727, 'X[0] <= -1.625\nsquared_error = 2086170051.531\nsamples = 3069\nvalue = 272278.397'),
#  Text(0.010023400378084711, 0.875, 'X[0] <= -1.83\nsquared_error = 878475669.536\nsamples = 200\nvalue = 213276.38'),
#  Text(0.004909242638418175, 0.8522727272727273, 'X[0] <= -2.651\nsquared_error = 366037098.18\nsamples = 123\nvalue = 200966.569'),
#  Text(0.004630209309058705, 0.8295454545454546, 'squared_error = 48987654.321\nsamples = 9\nvalue = 174888.889'),
#  Text(0.005188275967777645, 0.8295454545454546, 'X[1] <= 1969.5\nsquared_error = 333141012.117\nsamples = 114\nvalue = 203025.333'),
#  Text(0.001813716640836555, 0.8068181818181818, 'X[12] <= 0.5\nsquared_error = 195144724.196\nsamples = 30\nvalue = 191062.933'),
#  Text(0.00111613331743788, 0.7840909090909091, 'X[1] <= 1967.5\nsquared_error = 106543371.61\nsamples = 21\nvalue = 196089.905'),
#  Text(0.00055806665871894, 0.7613636363636364, 'X[0] <= -2.241\nsquared_error = 120511735.0\nsamples = 16\nvalue = 194243.0'),
#  Text(0.00027903332935947, 0.7386363636363636, 'squared_error = 2250000.0\nsamples = 2\nvalue = 179500.0'),
#  Text(0.00083709998807841, 0.7386363636363636, 'X[0] <= -2.077\nsquared_error = 101919566.694\nsamples = 14\nvalue = 196349.143'),
#  Text(0.00055806665871894, 0.7159090909090909, 'X[0] <= -2.2\nsquared_error = 111499218.512\nsamples = 11\nvalue = 197626.182'),
#  Text(0.00027903332935947, 0.6931818181818182, 'squared_error = 115840352.0\nsamples = 4\nvalue = 199472.0'),
#  Text(0.00083709998807841, 0.6931818181818182, 'X[25] <= 0.5\nsquared_error = 105959183.673\nsamples = 7\nvalue = 196571.429'),
#  Text(0.00055806665871894, 0.6704545454545454, 'squared_error = 123583333.333\nsamples = 6\nvalue = 196500.0'),
#  Text(0.00111613331743788, 0.6704545454545454, 'squared_error = 0.0\nsamples = 1\nvalue = 197000.0'),
#  Text(0.00111613331743788, 0.7159090909090909, 'squared_error = 38888888.889\nsamples = 3\nvalue = 191666.667'),
#  Text(0.00167419997615682, 0.7613636363636364, 'X[0] <= -2.241\nsquared_error = 16000000.0\nsamples = 5\nvalue = 202000.0'),
#  Text(0.00139516664679735, 0.7386363636363636, 'squared_error = 22222222.222\nsamples = 3\nvalue = 203333.333'),
#  Text(0.00195323330551629, 0.7386363636363636, 'squared_error = 0.0\nsamples = 2\nvalue = 200000.0'),
#  Text(0.00251129996423523, 0.7840909090909091, 'X[1] <= 1968.0\nsquared_error = 205333333.333\nsamples = 9\nvalue = 179333.333'),
#  Text(0.00223226663487576, 0.7613636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 195000.0'),
#  Text(0.0027903332935947, 0.7613636363636364, 'X[0] <= -2.2\nsquared_error = 196484375.0\nsamples = 8\nvalue = 177375.0'),
#  Text(0.00251129996423523, 0.7386363636363636, 'squared_error = 130640000.0\nsamples = 5\nvalue = 179600.0'),
#  Text(0.00306936662295417, 0.7386363636363636, 'squared_error = 284222222.222\nsamples = 3\nvalue = 173666.667'),
#  Text(0.008562835294718735, 0.8068181818181818, 'X[6] <= 0.5\nsquared_error = 313066184.807\nsamples = 84\nvalue = 207297.619'),
#  Text(0.006034095747398539, 0.7840909090909091, 'X[16] <= 0.5\nsquared_error = 244669607.225\nsamples = 69\nvalue = 204623.188'),
#  Text(0.004673808266771122, 0.7613636363636364, 'X[30] <= 0.5\nsquared_error = 197959987.689\nsamples = 57\nvalue = 201596.491'),
#  Text(0.00362743328167311, 0.7386363636363636, 'X[1] <= 1971.5\nsquared_error = 195353600.0\nsamples = 50\nvalue = 199920.0'),
#  Text(0.002371783299555495, 0.7159090909090909, 'X[0] <= -2.302\nsquared_error = 26560000.0\nsamples = 5\nvalue = 183800.0'),
#  Text(0.002092749970196025, 0.6931818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 176000.0'),
#  Text(0.002650816628914965, 0.6931818181818182, 'X[0] <= -2.2\nsquared_error = 14187500.0\nsamples = 4\nvalue = 185750.0'),
#  Text(0.002371783299555495, 0.6704545454545454, 'squared_error = 4222222.222\nsamples = 3\nvalue = 187666.667'),
#  Text(0.002929849958274435, 0.6704545454545454, 'squared_error = 0.0\nsamples = 1\nvalue = 180000.0'),
#  Text(0.004883083263790725, 0.7159090909090909, 'X[26] <= 0.5\nsquared_error = 182027654.321\nsamples = 45\nvalue = 201711.111'),
#  Text(0.004604049934431255, 0.6931818181818182, 'X[2] <= 0.5\nsquared_error = 162790805.785\nsamples = 44\nvalue = 202431.818'),
#  Text(0.003487916616993375, 0.6704545454545454, 'X[15] <= 0.5\nsquared_error = 142316290.131\nsamples = 29\nvalue = 205551.724'),
#  Text(0.002929849958274435, 0.6477272727272727, 'X[1] <= 1972.5\nsquared_error = 124718792.867\nsamples = 27\nvalue = 206851.852'),
#  Text(0.002650816628914965, 0.625, 'squared_error = 36000000.0\nsamples = 2\nvalue = 221000.0'),
#  Text(0.003208883287633905, 0.625, 'X[1] <= 1984.5\nsquared_error = 114521600.0\nsamples = 25\nvalue = 205720.0'),
#  Text(0.002650816628914965, 0.6022727272727273, 'X[1] <= 1981.0\nsquared_error = 63440000.0\nsamples = 15\nvalue = 202400.0'),
#  Text(0.002371783299555495, 0.5795454545454546, 'X[23] <= 0.5\nsquared_error = 52102040.816\nsamples = 14\nvalue = 203428.571'),
#  Text(0.002092749970196025, 0.5568181818181818, 'X[12] <= 0.5\nsquared_error = 48187500.0\nsamples = 12\nvalue = 202750.0'),
#  Text(0.001534683311477085, 0.5340909090909091, 'X[0] <= -2.159\nsquared_error = 55750000.0\nsamples = 8\nvalue = 203500.0'),
#  Text(0.001255649982117615, 0.5113636363636364, 'X[3] <= 0.5\nsquared_error = 48472222.222\nsamples = 6\nvalue = 202166.667'),
#  Text(0.000976616652758145, 0.48863636363636365, 'squared_error = 0.0\nsamples = 2\nvalue = 205000.0'),
#  Text(0.001534683311477085, 0.48863636363636365, 'squared_error = 66687500.0\nsamples = 4\nvalue = 200750.0'),
#  Text(0.001813716640836555, 0.5113636363636364, 'squared_error = 56250000.0\nsamples = 2\nvalue = 207500.0'),
#  Text(0.002650816628914965, 0.5340909090909091, 'X[1] <= 1976.0\nsquared_error = 29687500.0\nsamples = 4\nvalue = 201250.0'),
#  Text(0.002371783299555495, 0.5113636363636364, 'squared_error = 38888888.889\nsamples = 3\nvalue = 201666.667'),
#  Text(0.002929849958274435, 0.5113636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 200000.0'),
#  Text(0.002650816628914965, 0.5568181818181818, 'squared_error = 56250000.0\nsamples = 2\nvalue = 207500.0'),
#  Text(0.002929849958274435, 0.5795454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 188000.0'),
#  Text(0.003766949946352845, 0.6022727272727273, 'X[0] <= -2.241\nsquared_error = 149810000.0\nsamples = 10\nvalue = 210700.0'),
#  Text(0.003487916616993375, 0.5795454545454546, 'squared_error = 96555555.556\nsamples = 6\nvalue = 205333.333'),
#  Text(0.004045983275712315, 0.5795454545454546, 'squared_error = 121687500.0\nsamples = 4\nvalue = 218750.0'),
#  Text(0.004045983275712315, 0.6477272727272727, 'X[0] <= -2.097\nsquared_error = 49000000.0\nsamples = 2\nvalue = 188000.0'),
#  Text(0.003766949946352845, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 181000.0'),
#  Text(0.004325016605071785, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 195000.0'),
#  Text(0.005720183251869135, 0.6704545454545454, 'X[1] <= 1978.5\nsquared_error = 147173333.333\nsamples = 15\nvalue = 196400.0'),
#  Text(0.005162116593150195, 0.6477272727272727, 'X[1] <= 1977.5\nsquared_error = 12250000.0\nsamples = 4\nvalue = 189500.0'),
#  Text(0.004883083263790725, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 190000.0'),
#  Text(0.005441149922509665, 0.625, 'squared_error = 16222222.222\nsamples = 3\nvalue = 189333.333'),
#  Text(0.006278249910588075, 0.6477272727272727, 'X[1] <= 1979.5\nsquared_error = 172628099.174\nsamples = 11\nvalue = 198909.091'),
#  Text(0.005999216581228605, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 223000.0'),
#  Text(0.006557283239947545, 0.625, 'X[0] <= -2.159\nsquared_error = 126050000.0\nsamples = 10\nvalue = 196500.0'),
#  Text(0.006278249910588075, 0.6022727272727273, 'squared_error = 43687500.0\nsamples = 4\nvalue = 197250.0'),
#  Text(0.006836316569307015, 0.6022727272727273, 'squared_error = 180333333.333\nsamples = 6\nvalue = 196000.0'),
#  Text(0.005162116593150195, 0.6931818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 170000.0'),
#  Text(0.005720183251869135, 0.7386363636363636, 'X[0] <= -1.871\nsquared_error = 53102040.816\nsamples = 7\nvalue = 213571.429'),
#  Text(0.005441149922509665, 0.7159090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 220000.0'),
#  Text(0.005999216581228605, 0.7159090909090909, 'squared_error = 53916666.667\nsamples = 6\nvalue = 212500.0'),
#  Text(0.007394383228025955, 0.7613636363636364, 'X[1] <= 1974.5\nsquared_error = 216333333.333\nsamples = 12\nvalue = 219000.0'),
#  Text(0.006836316569307015, 0.7386363636363636, 'X[0] <= -1.974\nsquared_error = 127750000.0\nsamples = 8\nvalue = 212000.0'),
#  Text(0.006557283239947545, 0.7159090909090909, 'squared_error = 133000000.0\nsamples = 6\nvalue = 211000.0'),
#  Text(0.007115349898666485, 0.7159090909090909, 'squared_error = 100000000.0\nsamples = 2\nvalue = 215000.0'),
#  Text(0.007952449886744895, 0.7386363636363636, 'X[38] <= 0.5\nsquared_error = 99500000.0\nsamples = 4\nvalue = 233000.0'),
#  Text(0.007673416557385425, 0.7159090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 250000.0'),
#  Text(0.008231483216104365, 0.7159090909090909, 'X[0] <= -2.159\nsquared_error = 4222222.222\nsamples = 3\nvalue = 227333.333'),
#  Text(0.007952449886744895, 0.6931818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 230000.0'),
#  Text(0.008510516545463835, 0.6931818181818182, 'squared_error = 1000000.0\nsamples = 2\nvalue = 226000.0'),
#  Text(0.011091574842038933, 0.7840909090909091, 'X[1] <= 1974.5\nsquared_error = 443440000.0\nsamples = 15\nvalue = 219600.0'),
#  Text(0.01032423318630039, 0.7613636363636364, 'X[1] <= 1970.5\nsquared_error = 212290000.0\nsamples = 10\nvalue = 211900.0'),
#  Text(0.009626649862901715, 0.7386363636363636, 'X[0] <= -2.035\nsquared_error = 319040000.0\nsamples = 5\nvalue = 217600.0'),
#  Text(0.009347616533542245, 0.7159090909090909, 'X[0] <= -2.159\nsquared_error = 268750000.0\nsamples = 4\nvalue = 212500.0'),
#  Text(0.009068583204182775, 0.6931818181818182, 'X[0] <= -2.241\nsquared_error = 288888888.889\nsamples = 3\nvalue = 216666.667'),
#  Text(0.008789549874823305, 0.6704545454545454, 'squared_error = 0.0\nsamples = 1\nvalue = 210000.0'),
#  Text(0.009347616533542245, 0.6704545454545454, 'squared_error = 400000000.0\nsamples = 2\nvalue = 220000.0'),
#  Text(0.009626649862901715, 0.6931818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 200000.0'),
#  Text(0.009905683192261185, 0.7159090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 238000.0'),
#  Text(0.011021816509699064, 0.7386363636363636, 'X[0] <= -2.2\nsquared_error = 40560000.0\nsamples = 5\nvalue = 206200.0'),
#  Text(0.010463749850980125, 0.7159090909090909, 'X[1] <= 1972.0\nsquared_error = 6250000.0\nsamples = 2\nvalue = 202500.0'),
#  Text(0.010184716521620655, 0.6931818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 205000.0'),
#  Text(0.010742783180339594, 0.6931818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 200000.0'),
#  Text(0.011579883168418004, 0.7159090909090909, 'X[1] <= 1972.0\nsquared_error = 48222222.222\nsamples = 3\nvalue = 208666.667'),
#  Text(0.011300849839058534, 0.6931818181818182, 'squared_error = 64000000.0\nsamples = 2\nvalue = 207000.0'),
#  Text(0.011858916497777474, 0.6931818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 212000.0'),
#  Text(0.011858916497777474, 0.7613636363636364, 'X[0] <= -2.159\nsquared_error = 550000000.0\nsamples = 5\nvalue = 235000.0'),
#  Text(0.011579883168418004, 0.7386363636363636, 'squared_error = 0.0\nsamples = 1\nvalue = 215000.0'),
#  Text(0.012137949827136944, 0.7386363636363636, 'squared_error = 562500000.0\nsamples = 4\nvalue = 240000.0'),
#  Text(0.015137558117751247, 0.8522727272727273, 'X[6] <= 0.5\nsquared_error = 1068327614.327\nsamples = 77\nvalue = 232940.104'),
#  Text(0.01423069979733297, 0.8295454545454546, 'X[16] <= 0.5\nsquared_error = 882965976.365\nsamples = 67\nvalue = 227625.194'),
#  Text(0.013254083144574824, 0.8068181818181818, 'X[0] <= -1.748\nsquared_error = 947768386.108\nsamples = 57\nvalue = 230734.877'),
#  Text(0.012696016485855884, 0.7840909090909091, 'X[38] <= 0.5\nsquared_error = 6250000.0\nsamples = 2\nvalue = 197500.0'),
#  Text(0.012416983156496414, 0.7613636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 200000.0'),
#  Text(0.012975049815215354, 0.7613636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 195000.0'),
#  Text(0.013812149803293766, 0.7840909090909091, 'X[1] <= 1967.5\nsquared_error = 940379135.661\nsamples = 55\nvalue = 231943.418'),
#  Text(0.013533116473934296, 0.7613636363636364, 'squared_error = 74888888.889\nsamples = 3\nvalue = 251666.667'),
#  Text(0.014091183132653236, 0.7613636363636364, 'X[20] <= 0.5\nsquared_error = 966573810.556\nsamples = 52\nvalue = 230805.538'),
#  Text(0.013812149803293766, 0.7386363636363636, 'X[0] <= -1.707\nsquared_error = 1013705966.964\nsamples = 47\nvalue = 229827.404'),
#  Text(0.013254083144574824, 0.7159090909090909, 'X[1] <= 1970.0\nsquared_error = 98666666.667\nsamples = 3\nvalue = 216000.0'),
#  Text(0.012975049815215354, 0.6931818181818182, 'squared_error = 121000000.0\nsamples = 2\nvalue = 219000.0'),
#  Text(0.013533116473934296, 0.6931818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 210000.0'),
#  Text(0.014370216462012706, 0.7159090909090909, 'X[1] <= 1972.0\nsquared_error = 1062170014.149\nsamples = 44\nvalue = 230770.182'),
#  Text(0.014091183132653236, 0.6931818181818182, 'X[1] <= 1968.5\nsquared_error = 1141788465.76\nsamples = 40\nvalue = 231597.2'),
#  Text(0.013812149803293766, 0.6704545454545454, 'squared_error = 151250000.0\nsamples = 6\nvalue = 225500.0'),
#  Text(0.014370216462012706, 0.6704545454545454, 'X[1] <= 1970.0\nsquared_error = 1308871202.381\nsamples = 34\nvalue = 232673.176'),
#  Text(0.014091183132653236, 0.6477272727272727, 'squared_error = 1443512921.798\nsamples = 29\nvalue = 231927.172'),
#  Text(0.014649249791372176, 0.6477272727272727, 'squared_error = 506000000.0\nsamples = 5\nvalue = 237000.0'),
#  Text(0.014649249791372176, 0.6931818181818182, 'squared_error = 190750000.0\nsamples = 4\nvalue = 222500.0'),
#  Text(0.014370216462012706, 0.7386363636363636, 'squared_error = 430000000.0\nsamples = 5\nvalue = 240000.0'),
#  Text(0.015207316450091116, 0.8068181818181818, 'X[1] <= 1970.5\nsquared_error = 144290000.0\nsamples = 10\nvalue = 209900.0'),
#  Text(0.014928283120731646, 0.7840909090909091, 'X[0] <= -1.748\nsquared_error = 129687500.0\nsamples = 4\nvalue = 215250.0'),
#  Text(0.014649249791372176, 0.7613636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 202000.0'),
#  Text(0.015207316450091116, 0.7613636363636364, 'squared_error = 94888888.889\nsamples = 3\nvalue = 219666.667'),
#  Text(0.015486349779450586, 0.7840909090909091, 'squared_error = 122222222.222\nsamples = 6\nvalue = 206333.333'),
#  Text(0.016044416438169524, 0.8295454545454546, 'X[0] <= -1.789\nsquared_error = 852922500.0\nsamples = 10\nvalue = 268550.0'),
#  Text(0.015765383108810056, 0.8068181818181818, 'squared_error = 338888888.889\nsamples = 3\nvalue = 233333.333'),
#  Text(0.016323449767528996, 0.8068181818181818, 'X[29] <= 0.5\nsquared_error = 313908163.265\nsamples = 7\nvalue = 283642.857'),
#  Text(0.016044416438169524, 0.7840909090909091, 'X[0] <= -1.728\nsquared_error = 330034722.222\nsamples = 6\nvalue = 285916.667'),
#  Text(0.015765383108810056, 0.7613636363636364, 'squared_error = 395440000.0\nsamples = 5\nvalue = 285600.0'),
#  Text(0.016323449767528996, 0.7613636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 287500.0'),
#  Text(0.016602483096888464, 0.7840909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 270000.0'),
#  Text(0.12877603915666858, 0.875, 'X[15] <= 0.5\nsquared_error = 1910762375.589\nsamples = 2869\nvalue = 276391.468'),
#  Text(0.12137046140511638, 0.8522727272727273, 'X[24] <= 0.5\nsquared_error = 1854869142.755\nsamples = 2665\nvalue = 279405.763'),
#  Text(0.11566276827236469, 0.8295454545454546, 'X[4] <= 0.5\nsquared_error = 1816424586.473\nsamples = 2518\nvalue = 276932.284'),
#  Text(0.10853751944576315, 0.8068181818181818, 'X[26] <= 0.5\nsquared_error = 1695777395.656\nsamples = 2488\nvalue = 275776.001'),
#  Text(0.09815860923742273, 0.7840909090909091, 'X[16] <= 0.5\nsquared_error = 1655055915.38\nsamples = 2385\nvalue = 277652.255'),
#  Text(0.08619033869556517, 0.7613636363636364, 'X[20] <= 0.5\nsquared_error = 1567443796.135\nsamples = 2247\nvalue = 275572.684'),
#  Text(0.07184556830858184, 0.7386363636363636, 'X[6] <= 0.5\nsquared_error = 1405903714.806\nsamples = 2098\nvalue = 273370.301'),
#  Text(0.05096896075668035, 0.7159090909090909, 'X[1] <= 1973.5\nsquared_error = 1287947470.76\nsamples = 1947\nvalue = 271074.013'),
#  Text(0.02006424033925439, 0.6931818181818182, 'X[0] <= -1.496\nsquared_error = 1012464063.179\nsamples = 223\nvalue = 245718.758'),
#  Text(0.01646296643220873, 0.6704545454545454, 'X[38] <= 0.5\nsquared_error = 293498028.71\nsamples = 40\nvalue = 220381.7'),
#  Text(0.015207316450091116, 0.6477272727272727, 'X[0] <= -1.543\nsquared_error = 201962199.209\nsamples = 31\nvalue = 224911.871'),
#  Text(0.014091183132653236, 0.625, 'X[1] <= 1968.0\nsquared_error = 320288248.96\nsamples = 10\nvalue = 228288.8'),
#  Text(0.013812149803293766, 0.6022727272727273, 'squared_error = 210888888.889\nsamples = 3\nvalue = 239333.333'),
#  Text(0.014370216462012706, 0.6022727272727273, 'X[1] <= 1970.0\nsquared_error = 292491005.388\nsamples = 7\nvalue = 223555.429'),
#  Text(0.014091183132653236, 0.5795454545454546, 'squared_error = 133541136.0\nsamples = 2\nvalue = 218444.0'),
#  Text(0.014649249791372176, 0.5795454545454546, 'X[1] <= 1971.5\nsquared_error = 341440000.0\nsamples = 5\nvalue = 225600.0'),
#  Text(0.014370216462012706, 0.5568181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 228000.0'),
#  Text(0.014928283120731646, 0.5568181818181818, 'squared_error = 425000000.0\nsamples = 4\nvalue = 225000.0'),
#  Text(0.016323449767528996, 0.625, 'X[0] <= -1.516\nsquared_error = 137600290.249\nsamples = 21\nvalue = 223303.81'),
#  Text(0.016044416438169524, 0.6022727272727273, 'X[1] <= 1970.0\nsquared_error = 92551210.204\nsamples = 14\nvalue = 224384.286'),
#  Text(0.015765383108810056, 0.5795454545454546, 'X[25] <= 0.5\nsquared_error = 95744454.438\nsamples = 13\nvalue = 224913.846'),
#  Text(0.015486349779450586, 0.5568181818181818, 'X[1] <= 1968.0\nsquared_error = 58469135.802\nsamples = 9\nvalue = 226444.444'),
#  Text(0.015207316450091116, 0.5340909090909091, 'squared_error = 58693877.551\nsamples = 7\nvalue = 226142.857'),
#  Text(0.015765383108810056, 0.5340909090909091, 'squared_error = 56250000.0\nsamples = 2\nvalue = 227500.0'),
#  Text(0.016044416438169524, 0.5568181818181818, 'squared_error = 162482700.0\nsamples = 4\nvalue = 221470.0'),
#  Text(0.016323449767528996, 0.5795454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 217500.0'),
#  Text(0.016602483096888464, 0.6022727272727273, 'squared_error = 220693877.551\nsamples = 7\nvalue = 221142.857'),
#  Text(0.017718616414326344, 0.6477272727272727, 'X[25] <= 0.5\nsquared_error = 294617283.951\nsamples = 9\nvalue = 204777.778'),
#  Text(0.017439583084966875, 0.625, 'X[1] <= 1971.0\nsquared_error = 179387755.102\nsamples = 7\nvalue = 200428.571'),
#  Text(0.017160549755607404, 0.6022727272727273, 'squared_error = 198138888.889\nsamples = 6\nvalue = 199166.667'),
#  Text(0.017718616414326344, 0.6022727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 208000.0'),
#  Text(0.017997649743685815, 0.625, 'squared_error = 400000000.0\nsamples = 2\nvalue = 220000.0'),
#  Text(0.02366551424630005, 0.6704545454545454, 'X[1] <= 1970.5\nsquared_error = 998623404.725\nsamples = 183\nvalue = 251256.913'),
#  Text(0.02110189553280992, 0.6477272727272727, 'X[1] <= 1969.5\nsquared_error = 756576185.462\nsamples = 97\nvalue = 244263.66'),
#  Text(0.019602091387502768, 0.625, 'X[0] <= -1.255\nsquared_error = 719929142.244\nsamples = 45\nvalue = 240144.422'),
#  Text(0.018276683073045284, 0.6022727272727273, 'X[1] <= 1968.5\nsquared_error = 927966532.581\nsamples = 26\nvalue = 247230.731'),
#  Text(0.01730006642028714, 0.5795454545454546, 'X[1] <= 1967.5\nsquared_error = 698437434.953\nsamples = 19\nvalue = 250894.684'),
#  Text(0.0167419997615682, 0.5568181818181818, 'X[38] <= 0.5\nsquared_error = 719919398.026\nsamples = 14\nvalue = 247214.214'),
#  Text(0.01646296643220873, 0.5340909090909091, 'X[12] <= 0.5\nsquared_error = 6250000.0\nsamples = 2\nvalue = 257500.0'),
#  Text(0.01618393310284926, 0.5113636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 260000.0'),
#  Text(0.0167419997615682, 0.5113636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 255000.0'),
#  Text(0.01702103309092767, 0.5340909090909091, 'squared_error = 818292583.41\nsamples = 12\nvalue = 245499.917'),
#  Text(0.01785813307900608, 0.5568181818181818, 'X[0] <= -1.337\nsquared_error = 494160000.0\nsamples = 5\nvalue = 261200.0'),
#  Text(0.01757909974964661, 0.5340909090909091, 'squared_error = 506250000.0\nsamples = 2\nvalue = 255500.0'),
#  Text(0.01813716640836555, 0.5340909090909091, 'squared_error = 450000000.0\nsamples = 3\nvalue = 265000.0'),
#  Text(0.01925329972580343, 0.5795454545454546, 'X[25] <= 0.5\nsquared_error = 1415632653.061\nsamples = 7\nvalue = 237285.714'),
#  Text(0.01897426639644396, 0.5568181818181818, 'X[0] <= -1.461\nsquared_error = 1976000000.0\nsamples = 3\nvalue = 260000.0'),
#  Text(0.01869523306708449, 0.5340909090909091, 'squared_error = 81000000.0\nsamples = 2\nvalue = 229000.0'),
#  Text(0.01925329972580343, 0.5340909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 322000.0'),
#  Text(0.0195323330551629, 0.5568181818181818, 'squared_error = 318187500.0\nsamples = 4\nvalue = 220250.0'),
#  Text(0.02092749970196025, 0.6022727272727273, 'X[0] <= -1.112\nsquared_error = 272497229.917\nsamples = 19\nvalue = 230447.368'),
#  Text(0.02064846637260078, 0.5795454545454546, 'X[14] <= 0.5\nsquared_error = 217624228.395\nsamples = 18\nvalue = 228527.778'),
#  Text(0.02036943304324131, 0.5568181818181818, 'X[0] <= -1.214\nsquared_error = 231936523.438\nsamples = 16\nvalue = 229718.75'),
#  Text(0.01981136638452237, 0.5340909090909091, 'X[38] <= 0.5\nsquared_error = 306617283.951\nsamples = 9\nvalue = 233277.778'),
#  Text(0.0195323330551629, 0.5113636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 239500.0'),
#  Text(0.02009039971388184, 0.5113636363636364, 'squared_error = 339500000.0\nsamples = 8\nvalue = 232500.0'),
#  Text(0.02092749970196025, 0.5340909090909091, 'X[1] <= 1968.5\nsquared_error = 98693877.551\nsamples = 7\nvalue = 225142.857'),
#  Text(0.02064846637260078, 0.5113636363636364, 'squared_error = 8500000.0\nsamples = 4\nvalue = 229000.0'),
#  Text(0.02120653303131972, 0.5113636363636364, 'squared_error = 172666666.667\nsamples = 3\nvalue = 220000.0'),
#  Text(0.02092749970196025, 0.5568181818181818, 'squared_error = 1000000.0\nsamples = 2\nvalue = 219000.0'),
#  Text(0.02120653303131972, 0.5795454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 265000.0'),
#  Text(0.02260169967811707, 0.625, 'X[0] <= -1.255\nsquared_error = 760898761.391\nsamples = 52\nvalue = 247828.385'),
#  Text(0.02204363301939813, 0.6022727272727273, 'X[0] <= -1.296\nsquared_error = 483263714.38\nsamples = 11\nvalue = 229535.273'),
#  Text(0.02176459969003866, 0.5795454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 205000.0'),
#  Text(0.0223226663487576, 0.5795454545454546, 'squared_error = 465372328.96\nsamples = 10\nvalue = 231988.8'),
#  Text(0.02315976633683601, 0.6022727272727273, 'X[0] <= -1.214\nsquared_error = 721517740.012\nsamples = 41\nvalue = 252736.293'),
#  Text(0.02288073300747654, 0.5795454545454546, 'squared_error = 798337238.391\nsamples = 33\nvalue = 250854.182'),
#  Text(0.02343879966619548, 0.5795454545454546, 'squared_error = 329750000.0\nsamples = 8\nvalue = 260500.0'),
#  Text(0.02622913295979018, 0.6477272727272727, 'X[0] <= -1.296\nsquared_error = 1154252782.088\nsamples = 86\nvalue = 259144.651'),
#  Text(0.02483396631299283, 0.625, 'X[25] <= 0.5\nsquared_error = 819110183.474\nsamples = 42\nvalue = 269039.619'),
#  Text(0.02427589965427389, 0.6022727272727273, 'X[0] <= -1.438\nsquared_error = 168551020.408\nsamples = 14\nvalue = 251857.143'),
#  Text(0.02399686632491442, 0.5795454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 275000.0'),
#  Text(0.02455493298363336, 0.5795454545454546, 'X[1] <= 1971.5\nsquared_error = 137147928.994\nsamples = 13\nvalue = 250076.923'),
#  Text(0.02427589965427389, 0.5568181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 231000.0'),
#  Text(0.02483396631299283, 0.5568181818181818, 'squared_error = 115722222.222\nsamples = 12\nvalue = 251666.667'),
#  Text(0.02539203297171177, 0.6022727272727273, 'X[0] <= -1.461\nsquared_error = 922961648.98\nsamples = 28\nvalue = 277630.857'),
#  Text(0.0251129996423523, 0.5795454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 225000.0'),
#  Text(0.02567106630107124, 0.5795454545454546, 'X[1] <= 1972.5\nsquared_error = 850752821.904\nsamples = 27\nvalue = 279580.148'),
#  Text(0.02539203297171177, 0.5568181818181818, 'squared_error = 1464894920.992\nsamples = 11\nvalue = 289898.909'),
#  Text(0.02595009963043071, 0.5568181818181818, 'X[38] <= 0.5\nsquared_error = 305000372.0\nsamples = 16\nvalue = 272486.0'),
#  Text(0.02567106630107124, 0.5340909090909091, 'squared_error = 495250000.0\nsamples = 4\nvalue = 270500.0'),
#  Text(0.02622913295979018, 0.5340909090909091, 'squared_error = 239830853.333\nsamples = 12\nvalue = 273148.0'),
#  Text(0.02762429960658753, 0.625, 'X[1] <= 1972.5\nsquared_error = 1291489969.884\nsamples = 44\nvalue = 249699.455'),
#  Text(0.02734526627722806, 0.6022727272727273, 'X[1] <= 1971.5\nsquared_error = 1145566559.444\nsamples = 36\nvalue = 258316.333'),
#  Text(0.02678719961850912, 0.5795454545454546, 'X[25] <= 0.5\nsquared_error = 1348218727.619\nsamples = 21\nvalue = 254328.0'),
#  Text(0.02650816628914965, 0.5568181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 275000.0'),
#  Text(0.027066232947868592, 0.5568181818181818, 'squared_error = 1393194755.84\nsamples = 20\nvalue = 253294.4'),
#  Text(0.027903332935947, 0.5795454545454546, 'X[0] <= -1.255\nsquared_error = 808406666.667\nsamples = 15\nvalue = 263900.0'),
#  Text(0.02762429960658753, 0.5568181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 245000.0'),
#  Text(0.02818236626530647, 0.5568181818181818, 'X[0] <= -1.214\nsquared_error = 838812500.0\nsamples = 14\nvalue = 265250.0'),
#  Text(0.027903332935947, 0.5340909090909091, 'X[12] <= 0.5\nsquared_error = 625000000.0\nsamples = 2\nvalue = 283000.0'),
#  Text(0.02762429960658753, 0.5113636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 308000.0'),
#  Text(0.02818236626530647, 0.5113636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 258000.0'),
#  Text(0.02846139959466594, 0.5340909090909091, 'squared_error = 813185763.889\nsamples = 12\nvalue = 262291.667'),
#  Text(0.027903332935947, 0.6022727272727273, 'squared_error = 110442965.75\nsamples = 8\nvalue = 210923.5'),
#  Text(0.0818736811741063, 0.6931818181818182, 'X[17] <= 0.5\nsquared_error = 1229666926.811\nsamples = 1724\nvalue = 274353.724'),
#  Text(0.07751271139533696, 0.6704545454545454, 'X[8] <= 0.5\nsquared_error = 1154355227.496\nsamples = 1693\nvalue = 273189.026'),
#  Text(0.07046497181395507, 0.6477272727272727, 'X[5] <= 0.5\nsquared_error = 1091958640.015\nsamples = 1687\nvalue = 272714.595'),
#  Text(0.06023236030451147, 0.625, 'X[27] <= 0.5\nsquared_error = 1144996851.664\nsamples = 1486\nvalue = 275347.304'),
#  Text(0.0524893131461076, 0.6022727272727273, 'X[0] <= -1.173\nsquared_error = 1252538731.825\nsamples = 1234\nvalue = 278669.045'),
#  Text(0.04414908799836504, 0.5795454545454546, 'X[23] <= 0.5\nsquared_error = 1068201998.784\nsamples = 997\nvalue = 274574.534'),
#  Text(0.039384232845683535, 0.5568181818181818, 'X[12] <= 0.5\nsquared_error = 940625273.35\nsamples = 941\nvalue = 272801.43'),
#  Text(0.033769708942895584, 0.5340909090909091, 'X[11] <= 0.5\nsquared_error = 819319502.008\nsamples = 872\nvalue = 270652.603'),
#  Text(0.02874043292402541, 0.5113636363636364, 'X[38] <= 0.5\nsquared_error = 622719583.379\nsamples = 740\nvalue = 266898.1'),
#  Text(0.02359984331624572, 0.48863636363636365, 'X[3] <= 0.5\nsquared_error = 570635369.523\nsamples = 616\nvalue = 269756.097'),
#  Text(0.019562034845104485, 0.4659090909090909, 'X[1] <= 1979.5\nsquared_error = 466842129.319\nsamples = 392\nvalue = 264692.388'),
#  Text(0.015743856123439547, 0.4431818181818182, 'X[1] <= 1978.5\nsquared_error = 393222048.284\nsamples = 112\nvalue = 257689.964'),
#  Text(0.01490675613536114, 0.42045454545454547, 'X[2] <= 0.5\nsquared_error = 415453985.842\nsamples = 57\nvalue = 261859.649'),
#  Text(0.01462772280600167, 0.3977272727272727, 'squared_error = 20750000.0\nsamples = 4\nvalue = 254500.0'),
#  Text(0.015185789464720609, 0.3977272727272727, 'X[1] <= 1976.5\nsquared_error = 440846564.614\nsamples = 53\nvalue = 262415.094'),
#  Text(0.01490675613536114, 0.375, 'squared_error = 227440000.0\nsamples = 5\nvalue = 258400.0'),
#  Text(0.015464822794080079, 0.375, 'X[1] <= 1977.5\nsquared_error = 461222222.222\nsamples = 48\nvalue = 262833.333'),
#  Text(0.015185789464720609, 0.3522727272727273, 'squared_error = 208955017.301\nsamples = 17\nvalue = 263470.588'),
#  Text(0.015743856123439547, 0.3522727272727273, 'squared_error = 599217481.79\nsamples = 31\nvalue = 262483.871'),
#  Text(0.01658095611151796, 0.42045454545454547, 'X[10] <= 0.5\nsquared_error = 333489459.062\nsamples = 55\nvalue = 253368.655'),
#  Text(0.01630192278215849, 0.3977272727272727, 'X[0] <= -1.214\nsquared_error = 328667261.982\nsamples = 52\nvalue = 254370.692'),
#  Text(0.01602288945279902, 0.375, 'squared_error = 329701957.69\nsamples = 50\nvalue = 254845.52'),
#  Text(0.01658095611151796, 0.375, 'squared_error = 156250000.0\nsamples = 2\nvalue = 242500.0'),
#  Text(0.01685998944087743, 0.3977272727272727, 'squared_error = 98000000.0\nsamples = 3\nvalue = 236000.0'),
#  Text(0.02338021356676942, 0.4431818181818182, 'X[25] <= 0.5\nsquared_error = 468831158.444\nsamples = 280\nvalue = 267493.357'),
#  Text(0.021494558645707377, 0.42045454545454547, 'X[13] <= 0.5\nsquared_error = 435349475.649\nsamples = 270\nvalue = 266589.407'),
#  Text(0.0185603487916617, 0.3977272727272727, 'X[1] <= 1985.5\nsquared_error = 486601495.79\nsamples = 205\nvalue = 265137.815'),
#  Text(0.017261099851831666, 0.375, 'X[1] <= 1980.5\nsquared_error = 491600132.315\nsamples = 197\nvalue = 265750.579'),
#  Text(0.01630192278215849, 0.3522727272727273, 'X[0] <= -1.214\nsquared_error = 356581817.671\nsamples = 73\nvalue = 268872.438'),
#  Text(0.01602288945279902, 0.32954545454545453, 'squared_error = 379946592.798\nsamples = 19\nvalue = 263515.789'),
#  Text(0.01658095611151796, 0.32954545454545453, 'squared_error = 334712680.669\nsamples = 54\nvalue = 270757.185'),
#  Text(0.018220276921504845, 0.3522727272727273, 'X[1] <= 1981.5\nsquared_error = 561971389.174\nsamples = 124\nvalue = 263912.71'),
#  Text(0.0171390227702369, 0.32954545454545453, 'X[0] <= -1.214\nsquared_error = 567885206.612\nsamples = 44\nvalue = 258354.545'),
#  Text(0.01685998944087743, 0.3068181818181818, 'squared_error = 57555555.556\nsamples = 3\nvalue = 227666.667'),
#  Text(0.01741805609959637, 0.3068181818181818, 'X[10] <= 0.5\nsquared_error = 531276097.561\nsamples = 41\nvalue = 260600.0'),
#  Text(0.0171390227702369, 0.2840909090909091, 'squared_error = 549575456.538\nsamples = 37\nvalue = 261745.946'),
#  Text(0.01769708942895584, 0.2840909090909091, 'squared_error = 237500000.0\nsamples = 4\nvalue = 250000.0'),
#  Text(0.01930153107277279, 0.32954545454545453, 'X[1] <= 1982.5\nsquared_error = 532382345.51\nsamples = 80\nvalue = 266969.7'),
#  Text(0.01853418941703425, 0.3068181818181818, 'X[0] <= -1.214\nsquared_error = 937061728.395\nsamples = 9\nvalue = 287277.778'),
#  Text(0.01825515608767478, 0.2840909090909091, 'squared_error = 162500000.0\nsamples = 3\nvalue = 282500.0'),
#  Text(0.01881322274639372, 0.2840909090909091, 'squared_error = 1307222222.222\nsamples = 6\nvalue = 289666.667'),
#  Text(0.020068872728511333, 0.3068181818181818, 'X[0] <= -1.214\nsquared_error = 422179786.049\nsamples = 71\nvalue = 264395.437'),
#  Text(0.01937128940511266, 0.2840909090909091, 'X[1] <= 1984.5\nsquared_error = 355062385.017\nsamples = 44\nvalue = 267804.273'),
#  Text(0.01881322274639372, 0.26136363636363635, 'X[2] <= 0.5\nsquared_error = 391186294.282\nsamples = 35\nvalue = 266453.943'),
#  Text(0.01853418941703425, 0.23863636363636365, 'X[1] <= 1983.5\nsquared_error = 333427937.097\nsamples = 27\nvalue = 267847.704'),
#  Text(0.01825515608767478, 0.2159090909090909, 'squared_error = 317283820.333\nsamples = 24\nvalue = 266537.0'),
#  Text(0.01881322274639372, 0.2159090909090909, 'squared_error = 338888888.889\nsamples = 3\nvalue = 278333.333'),
#  Text(0.01909225607575319, 0.23863636363636365, 'squared_error = 557437500.0\nsamples = 8\nvalue = 261750.0'),
#  Text(0.0199293560638316, 0.26136363636363635, 'X[14] <= 0.5\nsquared_error = 179913580.247\nsamples = 9\nvalue = 273055.556'),
#  Text(0.01965032273447213, 0.23863636363636365, 'squared_error = 211551020.408\nsamples = 7\nvalue = 275142.857'),
#  Text(0.02020838939319107, 0.23863636363636365, 'squared_error = 562500.0\nsamples = 2\nvalue = 265750.0'),
#  Text(0.02076645605191001, 0.2840909090909091, 'X[1] <= 1984.0\nsquared_error = 481760144.505\nsamples = 27\nvalue = 258840.296'),
#  Text(0.02048742272255054, 0.26136363636363635, 'squared_error = 578327548.454\nsamples = 19\nvalue = 262720.421'),
#  Text(0.02104548938126948, 0.26136363636363635, 'X[14] <= 0.5\nsquared_error = 131734375.0\nsamples = 8\nvalue = 249625.0'),
#  Text(0.02076645605191001, 0.23863636363636365, 'squared_error = 8222222.222\nsamples = 3\nvalue = 259666.667'),
#  Text(0.02132452271062895, 0.23863636363636365, 'squared_error = 109040000.0\nsamples = 5\nvalue = 243600.0'),
#  Text(0.01985959773149173, 0.375, 'X[49] <= 0.5\nsquared_error = 126576465.75\nsamples = 8\nvalue = 250048.5'),
#  Text(0.019580564402132263, 0.3522727272727273, 'squared_error = 299497636.0\nsamples = 2\nvalue = 247694.0'),
#  Text(0.020138631060851203, 0.3522727272727273, 'X[1] <= 1987.5\nsquared_error = 66472222.222\nsamples = 6\nvalue = 250833.333'),
#  Text(0.01985959773149173, 0.32954545454545453, 'squared_error = 0.0\nsamples = 1\nvalue = 260000.0'),
#  Text(0.02041766439021067, 0.32954545454545453, 'squared_error = 59600000.0\nsamples = 5\nvalue = 249000.0'),
#  Text(0.02442876849975305, 0.3977272727272727, 'X[49] <= 0.5\nsquared_error = 246103949.542\nsamples = 65\nvalue = 271167.508'),
#  Text(0.023626547677844577, 0.375, 'X[0] <= -1.214\nsquared_error = 289741059.303\nsamples = 47\nvalue = 273297.872'),
#  Text(0.022859206022106036, 0.3522727272727273, 'X[1] <= 1984.5\nsquared_error = 280620876.149\nsamples = 43\nvalue = 272534.884'),
#  Text(0.022161622698707358, 0.32954545454545453, 'X[1] <= 1982.5\nsquared_error = 305631944.444\nsamples = 36\nvalue = 273583.333'),
#  Text(0.02160355603998842, 0.3068181818181818, 'X[0] <= -1.255\nsquared_error = 298198347.107\nsamples = 11\nvalue = 269272.727'),
#  Text(0.02132452271062895, 0.2840909090909091, 'squared_error = 1225000000.0\nsamples = 2\nvalue = 283000.0'),
#  Text(0.02188258936934789, 0.2840909090909091, 'X[1] <= 1981.5\nsquared_error = 41061728.395\nsamples = 9\nvalue = 266222.222'),
#  Text(0.02160355603998842, 0.26136363636363635, 'squared_error = 33346938.776\nsamples = 7\nvalue = 268285.714'),
#  Text(0.022161622698707358, 0.26136363636363635, 'squared_error = 1000000.0\nsamples = 2\nvalue = 259000.0'),
#  Text(0.022719689357426298, 0.3068181818181818, 'X[1] <= 1983.5\nsquared_error = 297129600.0\nsamples = 25\nvalue = 275480.0'),
#  Text(0.02244065602806683, 0.2840909090909091, 'squared_error = 333058823.529\nsamples = 17\nvalue = 277000.0'),
#  Text(0.02299872268678577, 0.2840909090909091, 'squared_error = 205437500.0\nsamples = 8\nvalue = 272250.0'),
#  Text(0.02355678934550471, 0.32954545454545453, 'X[1] <= 1985.5\nsquared_error = 117265306.122\nsamples = 7\nvalue = 267142.857'),
#  Text(0.023277756016145238, 0.3068181818181818, 'squared_error = 132222222.222\nsamples = 6\nvalue = 266333.333'),
#  Text(0.023835822674864178, 0.3068181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 272000.0'),
#  Text(0.024393889333583118, 0.3522727272727273, 'X[1] <= 1984.0\nsquared_error = 314250000.0\nsamples = 4\nvalue = 281500.0'),
#  Text(0.02411485600422365, 0.32954545454545453, 'squared_error = 380250000.0\nsamples = 2\nvalue = 270500.0'),
#  Text(0.02467292266294259, 0.32954545454545453, 'squared_error = 6250000.0\nsamples = 2\nvalue = 292500.0'),
#  Text(0.02523098932166153, 0.375, 'X[1] <= 1986.5\nsquared_error = 89369472.988\nsamples = 18\nvalue = 265604.889'),
#  Text(0.024951955992302058, 0.3522727272727273, 'squared_error = 51624719.673\nsamples = 7\nvalue = 262412.571'),
#  Text(0.025510022651020998, 0.3522727272727273, 'X[1] <= 1988.5\nsquared_error = 102776859.504\nsamples = 11\nvalue = 267636.364'),
#  Text(0.02523098932166153, 0.32954545454545453, 'X[1] <= 1987.5\nsquared_error = 67187500.0\nsamples = 4\nvalue = 276250.0'),
#  Text(0.024951955992302058, 0.3068181818181818, 'squared_error = 0.0\nsamples = 2\nvalue = 270000.0'),
#  Text(0.025510022651020998, 0.3068181818181818, 'squared_error = 56250000.0\nsamples = 2\nvalue = 282500.0'),
#  Text(0.02578905598038047, 0.32954545454545453, 'squared_error = 56489795.918\nsamples = 7\nvalue = 262714.286'),
#  Text(0.025265868487831463, 0.42045454545454547, 'X[50] <= 0.5\nsquared_error = 755090000.0\nsamples = 10\nvalue = 291900.0'),
#  Text(0.02498683515847199, 0.3977272727272727, 'squared_error = 730472222.222\nsamples = 6\nvalue = 305166.667'),
#  Text(0.02554490181719093, 0.3977272727272727, 'squared_error = 132000000.0\nsamples = 4\nvalue = 272000.0'),
#  Text(0.027637651787386957, 0.4659090909090909, 'X[1] <= 1977.5\nsquared_error = 628875479.546\nsamples = 224\nvalue = 278617.589'),
#  Text(0.02735861845802749, 0.4431818181818182, 'squared_error = 312481467.568\nsamples = 19\nvalue = 266994.105'),
#  Text(0.02791668511674643, 0.4431818181818182, 'X[1] <= 1985.5\nsquared_error = 644517268.383\nsamples = 205\nvalue = 279694.888'),
#  Text(0.02666103513462881, 0.42045454545454547, 'X[0] <= -1.214\nsquared_error = 661656929.968\nsamples = 195\nvalue = 279294.626'),
#  Text(0.02610296847590987, 0.3977272727272727, 'X[1] <= 1978.5\nsquared_error = 473796643.288\nsamples = 94\nvalue = 277976.34'),
#  Text(0.025823935146550403, 0.375, 'squared_error = 437109261.186\nsamples = 31\nvalue = 279709.677'),
#  Text(0.026382001805269343, 0.375, 'X[1] <= 1980.5\nsquared_error = 489643322.34\nsamples = 63\nvalue = 277123.429'),
#  Text(0.02610296847590987, 0.3522727272727273, 'squared_error = 634945860.76\nsamples = 40\nvalue = 276422.2'),
#  Text(0.02666103513462881, 0.3522727272727273, 'X[1] <= 1983.0\nsquared_error = 234600839.259\nsamples = 23\nvalue = 278342.957'),
#  Text(0.026382001805269343, 0.32954545454545453, 'squared_error = 179387755.102\nsamples = 7\nvalue = 282428.571'),
#  Text(0.026940068463988283, 0.32954545454545453, 'X[1] <= 1984.5\nsquared_error = 248258703.75\nsamples = 16\nvalue = 276555.5'),
#  Text(0.02666103513462881, 0.3068181818181818, 'squared_error = 25000000.0\nsamples = 2\nvalue = 275000.0'),
#  Text(0.02721910179334775, 0.3068181818181818, 'squared_error = 279757770.776\nsamples = 14\nvalue = 276777.714'),
#  Text(0.02721910179334775, 0.3977272727272727, 'X[1] <= 1979.5\nsquared_error = 833374437.694\nsamples = 101\nvalue = 280521.545'),
#  Text(0.026940068463988283, 0.375, 'squared_error = 1217662851.197\nsamples = 31\nvalue = 283580.645'),
#  Text(0.027498135122707223, 0.375, 'X[1] <= 1980.5\nsquared_error = 657209936.16\nsamples = 70\nvalue = 279166.8'),
#  Text(0.02721910179334775, 0.3522727272727273, 'squared_error = 822347760.902\nsamples = 50\nvalue = 280095.76'),
#  Text(0.027777168452066694, 0.3522727272727273, 'X[1] <= 1981.5\nsquared_error = 236814415.84\nsamples = 20\nvalue = 276844.4'),
#  Text(0.027498135122707223, 0.32954545454545453, 'squared_error = 254221040.498\nsamples = 17\nvalue = 276405.176'),
#  Text(0.028056201781426163, 0.32954545454545453, 'squared_error = 130888888.889\nsamples = 3\nvalue = 279333.333'),
#  Text(0.029172335098864043, 0.42045454545454547, 'X[0] <= -1.379\nsquared_error = 246250000.0\nsamples = 10\nvalue = 287500.0'),
#  Text(0.028893301769504574, 0.3977272727272727, 'squared_error = 25000000.0\nsamples = 2\nvalue = 280000.0'),
#  Text(0.029451368428223514, 0.3977272727272727, 'X[1] <= 1987.5\nsquared_error = 283984375.0\nsamples = 8\nvalue = 289375.0'),
#  Text(0.029172335098864043, 0.375, 'X[1] <= 1986.5\nsquared_error = 234000000.0\nsamples = 5\nvalue = 286000.0'),
#  Text(0.028893301769504574, 0.3522727272727273, 'X[0] <= -1.296\nsquared_error = 154687500.0\nsamples = 4\nvalue = 291250.0'),
#  Text(0.028614268440145103, 0.32954545454545453, 'squared_error = 225000000.0\nsamples = 2\nvalue = 295000.0'),
#  Text(0.029172335098864043, 0.32954545454545453, 'squared_error = 56250000.0\nsamples = 2\nvalue = 287500.0'),
#  Text(0.029451368428223514, 0.3522727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 265000.0'),
#  Text(0.029730401757582983, 0.375, 'squared_error = 316666666.667\nsamples = 3\nvalue = 295000.0'),
#  Text(0.0338810225318051, 0.48863636363636365, 'X[1] <= 1981.5\nsquared_error = 639305918.003\nsamples = 124\nvalue = 252700.306'),
#  Text(0.031823151727779005, 0.4659090909090909, 'X[3] <= 0.5\nsquared_error = 596055786.461\nsamples = 82\nvalue = 247037.049'),
#  Text(0.030846535075020862, 0.4431818181818182, 'X[0] <= -1.255\nsquared_error = 456493055.556\nsamples = 24\nvalue = 229416.667'),
#  Text(0.030567501745661394, 0.42045454545454547, 'X[1] <= 1975.5\nsquared_error = 401618147.448\nsamples = 23\nvalue = 227652.174'),
#  Text(0.030288468416301922, 0.3977272727272727, 'squared_error = 100000000.0\nsamples = 2\nvalue = 205000.0'),
#  Text(0.030846535075020862, 0.3977272727272727, 'X[2] <= 0.5\nsquared_error = 376820861.678\nsamples = 21\nvalue = 229809.524'),
#  Text(0.030567501745661394, 0.375, 'X[1] <= 1980.5\nsquared_error = 347810000.0\nsamples = 20\nvalue = 228300.0'),
#  Text(0.030009435086942454, 0.3522727272727273, 'X[1] <= 1978.0\nsquared_error = 261183391.003\nsamples = 17\nvalue = 230588.235'),
#  Text(0.029730401757582983, 0.32954545454545453, 'squared_error = 115375000.0\nsamples = 16\nvalue = 227500.0'),
#  Text(0.030288468416301922, 0.32954545454545453, 'squared_error = 0.0\nsamples = 1\nvalue = 280000.0'),
#  Text(0.031125568404380334, 0.3522727272727273, 'X[18] <= 0.5\nsquared_error = 640888888.889\nsamples = 3\nvalue = 215333.333'),
#  Text(0.030846535075020862, 0.32954545454545453, 'squared_error = 25000000.0\nsamples = 2\nvalue = 233000.0'),
#  Text(0.0314046017337398, 0.32954545454545453, 'squared_error = 0.0\nsamples = 1\nvalue = 180000.0'),
#  Text(0.031125568404380334, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 260000.0'),
#  Text(0.031125568404380334, 0.42045454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 270000.0'),
#  Text(0.03279976838053715, 0.4431818181818182, 'X[1] <= 1977.5\nsquared_error = 472170792.838\nsamples = 58\nvalue = 254328.241'),
#  Text(0.032241701721818214, 0.42045454545454547, 'X[1] <= 1976.5\nsquared_error = 379053824.142\nsamples = 31\nvalue = 266188.71'),
#  Text(0.031962668392458746, 0.3977272727272727, 'X[1] <= 1975.0\nsquared_error = 246038400.0\nsamples = 25\nvalue = 263460.0'),
#  Text(0.03168363506309927, 0.375, 'squared_error = 162496093.75\nsamples = 8\nvalue = 259812.5'),
#  Text(0.032241701721818214, 0.375, 'X[0] <= -1.44\nsquared_error = 276145328.72\nsamples = 17\nvalue = 265176.471'),
#  Text(0.031962668392458746, 0.3522727272727273, 'squared_error = 604960000.0\nsamples = 5\nvalue = 263800.0'),
#  Text(0.03252073505117768, 0.3522727272727273, 'squared_error = 138020833.333\nsamples = 12\nvalue = 265750.0'),
#  Text(0.03252073505117768, 0.3977272727272727, 'squared_error = 772992013.889\nsamples = 6\nvalue = 277558.333'),
#  Text(0.033357835039256094, 0.42045454545454547, 'X[0] <= -1.42\nsquared_error = 232133713.778\nsamples = 27\nvalue = 240710.667'),
#  Text(0.033078801709896626, 0.3977272727272727, 'squared_error = 182505761.538\nsamples = 26\nvalue = 239238.0'),
#  Text(0.03363686836861556, 0.3977272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 279000.0'),
#  Text(0.03593889333583119, 0.4659090909090909, 'X[1] <= 1985.5\nsquared_error = 538875306.122\nsamples = 42\nvalue = 263757.143'),
#  Text(0.03475300168605344, 0.4431818181818182, 'X[13] <= 0.5\nsquared_error = 313893333.333\nsamples = 15\nvalue = 283200.0'),
#  Text(0.034473968356693974, 0.42045454545454547, 'X[3] <= 0.5\nsquared_error = 220899408.284\nsamples = 13\nvalue = 287153.846'),
#  Text(0.034194935027334505, 0.3977272727272727, 'squared_error = 222122448.98\nsamples = 7\nvalue = 281142.857'),
#  Text(0.03475300168605344, 0.3977272727272727, 'X[0] <= -1.42\nsquared_error = 128138888.889\nsamples = 6\nvalue = 294166.667'),
#  Text(0.034473968356693974, 0.375, 'squared_error = 196000000.0\nsamples = 2\nvalue = 286000.0'),
#  Text(0.03503203501541291, 0.375, 'squared_error = 44187500.0\nsamples = 4\nvalue = 298250.0'),
#  Text(0.03503203501541291, 0.42045454545454547, 'squared_error = 156250000.0\nsamples = 2\nvalue = 257500.0'),
#  Text(0.037124784985608936, 0.4431818181818182, 'X[2] <= 0.5\nsquared_error = 337177283.951\nsamples = 27\nvalue = 252955.556'),
#  Text(0.036427201662210265, 0.42045454545454547, 'X[1] <= 1986.5\nsquared_error = 361603305.785\nsamples = 22\nvalue = 255181.818'),
#  Text(0.03586913500349132, 0.3977272727272727, 'X[0] <= -1.502\nsquared_error = 424768166.09\nsamples = 17\nvalue = 254235.294'),
#  Text(0.035590101674131853, 0.375, 'squared_error = 450125000.0\nsamples = 16\nvalue = 254500.0'),
#  Text(0.03614816833285079, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 250000.0'),
#  Text(0.0369852683209292, 0.3977272727272727, 'X[1] <= 1987.5\nsquared_error = 133440000.0\nsamples = 5\nvalue = 258400.0'),
#  Text(0.03670623499156973, 0.375, 'squared_error = 0.0\nsamples = 1\nvalue = 260000.0'),
#  Text(0.03726430165028867, 0.375, 'squared_error = 166000000.0\nsamples = 4\nvalue = 258000.0'),
#  Text(0.03782236830900761, 0.42045454545454547, 'X[0] <= -1.502\nsquared_error = 111942400.0\nsamples = 5\nvalue = 243160.0'),
#  Text(0.037543334979648145, 0.3977272727272727, 'squared_error = 136807500.0\nsamples = 4\nvalue = 243950.0'),
#  Text(0.03810140163836708, 0.3977272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 240000.0'),
#  Text(0.03879898496176576, 0.5113636363636364, 'X[1] <= 1978.5\nsquared_error = 1399428732.153\nsamples = 132\nvalue = 291700.576'),
#  Text(0.03851995163240629, 0.48863636363636365, 'squared_error = 1580875171.468\nsamples = 27\nvalue = 318703.704'),
#  Text(0.03907801829112523, 0.48863636363636365, 'X[1] <= 1979.5\nsquared_error = 1117056062.555\nsamples = 105\nvalue = 284756.914'),
#  Text(0.03879898496176576, 0.4659090909090909, 'squared_error = 1093944344.511\nsamples = 47\nvalue = 294104.0'),
#  Text(0.039357051620484695, 0.4659090909090909, 'X[0] <= -1.214\nsquared_error = 1007615339.42\nsamples = 58\nvalue = 277182.552'),
#  Text(0.038659468297086025, 0.4431818181818182, 'X[1] <= 1982.0\nsquared_error = 1130042203.348\nsamples = 37\nvalue = 282069.946'),
#  Text(0.03838043496772655, 0.42045454545454547, 'squared_error = 1130473643.395\nsamples = 36\nvalue = 281155.222'),
#  Text(0.03893850162644549, 0.42045454545454547, 'squared_error = 0.0\nsamples = 1\nvalue = 315000.0'),
#  Text(0.04005463494388337, 0.4431818181818182, 'X[1] <= 1982.0\nsquared_error = 675673469.388\nsamples = 21\nvalue = 268571.429'),
#  Text(0.03949656828516443, 0.42045454545454547, 'X[1] <= 1980.5\nsquared_error = 582426666.667\nsamples = 15\nvalue = 264800.0'),
# ...
#  Text(0.11023151727779008, 0.6022727272727273, 'squared_error = 400000000.0\nsamples = 2\nvalue = 340000.0'),
#  Text(0.11078958393650902, 0.6022727272727273, 'squared_error = 12250000.0\nsamples = 2\nvalue = 353500.0'),
#  Text(0.1119057172539469, 0.625, 'X[1] <= 1984.0\nsquared_error = 244279097.222\nsamples = 12\nvalue = 366358.333'),
#  Text(0.11134765059522796, 0.6022727272727273, 'X[1] <= 1981.5\nsquared_error = 35870000.0\nsamples = 4\nvalue = 378700.0'),
#  Text(0.11106861726586849, 0.5795454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 380000.0'),
#  Text(0.11162668392458742, 0.5795454545454546, 'squared_error = 47075555.556\nsamples = 3\nvalue = 378266.667'),
#  Text(0.11246378391266584, 0.6022727272727273, 'X[1] <= 1986.5\nsquared_error = 234246093.75\nsamples = 8\nvalue = 360187.5'),
#  Text(0.11218475058330636, 0.5795454545454546, 'squared_error = 206000000.0\nsamples = 4\nvalue = 352000.0'),
#  Text(0.11274281724202531, 0.5795454545454546, 'squared_error = 128421875.0\nsamples = 4\nvalue = 368375.0'),
#  Text(0.11504484220924094, 0.6704545454545454, 'X[0] <= -1.255\nsquared_error = 1203626565.249\nsamples = 44\nvalue = 327104.977'),
#  Text(0.11385895055946318, 0.6477272727272727, 'X[1] <= 1980.5\nsquared_error = 1202077496.24\nsamples = 15\nvalue = 297754.6'),
#  Text(0.11330088390074425, 0.625, 'X[0] <= -1.296\nsquared_error = 1762000000.0\nsamples = 4\nvalue = 328000.0'),
#  Text(0.11302185057138478, 0.6022727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 260000.0'),
#  Text(0.11357991723010372, 0.6022727272727273, 'squared_error = 294222222.222\nsamples = 3\nvalue = 350666.667'),
#  Text(0.11441701721818212, 0.625, 'X[0] <= -1.296\nsquared_error = 544857302.562\nsamples = 11\nvalue = 286756.273'),
#  Text(0.11413798388882265, 0.6022727272727273, 'squared_error = 337072744.583\nsamples = 6\nvalue = 301886.5'),
#  Text(0.1146960505475416, 0.6022727272727273, 'squared_error = 189840000.0\nsamples = 5\nvalue = 268600.0'),
#  Text(0.11623073385901868, 0.6477272727272727, 'X[1] <= 1981.5\nsquared_error = 528383258.026\nsamples = 29\nvalue = 342286.207'),
#  Text(0.11553315053562001, 0.625, 'X[1] <= 1977.5\nsquared_error = 381294117.647\nsamples = 17\nvalue = 351000.0'),
#  Text(0.11525411720626054, 0.6022727272727273, 'squared_error = 0.0\nsamples = 1\nvalue = 395000.0'),
#  Text(0.11581218386497948, 0.6022727272727273, 'X[1] <= 1980.0\nsquared_error = 276562500.0\nsamples = 16\nvalue = 348250.0'),
#  Text(0.11525411720626054, 0.5795454545454546, 'X[45] <= 0.5\nsquared_error = 228094674.556\nsamples = 13\nvalue = 345538.462'),
#  Text(0.11497508387690107, 0.5568181818181818, 'X[0] <= -1.071\nsquared_error = 122916666.667\nsamples = 6\nvalue = 339500.0'),
#  Text(0.1146960505475416, 0.5340909090909091, 'squared_error = 74000000.0\nsamples = 5\nvalue = 336000.0'),
#  Text(0.11525411720626054, 0.5340909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 357000.0'),
#  Text(0.11553315053562001, 0.5568181818181818, 'squared_error = 260204081.633\nsamples = 7\nvalue = 350714.286'),
#  Text(0.11637025052369841, 0.5795454545454546, 'X[45] <= 0.5\nsquared_error = 316666666.667\nsamples = 3\nvalue = 360000.0'),
#  Text(0.11609121719433894, 0.5568181818181818, 'squared_error = 0.0\nsamples = 1\nvalue = 385000.0'),
#  Text(0.1166492838530579, 0.5568181818181818, 'squared_error = 6250000.0\nsamples = 2\nvalue = 347500.0'),
#  Text(0.11692831718241736, 0.625, 'X[0] <= -1.214\nsquared_error = 476804097.222\nsamples = 12\nvalue = 329941.667'),
#  Text(0.1166492838530579, 0.6022727272727273, 'squared_error = 544026172.84\nsamples = 9\nvalue = 334477.778'),
#  Text(0.11720735051177683, 0.6022727272727273, 'X[1] <= 1984.5\nsquared_error = 28222222.222\nsamples = 3\nvalue = 316333.333'),
#  Text(0.11692831718241736, 0.5795454545454546, 'squared_error = 9000000.0\nsamples = 2\nvalue = 313000.0'),
#  Text(0.1174863838411363, 0.5795454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 323000.0'),
#  Text(0.11316136723606451, 0.6931818181818182, 'squared_error = 68250000.0\nsamples = 4\nvalue = 269500.0'),
#  Text(0.11344040056542398, 0.7159090909090909, 'squared_error = 6250000.0\nsamples = 2\nvalue = 427500.0'),
#  Text(0.11891642965410358, 0.7840909090909091, 'X[1] <= 1988.5\nsquared_error = 669690159.6\nsamples = 103\nvalue = 232330.718'),
#  Text(0.11741662550879643, 0.7613636363636364, 'X[1] <= 1979.0\nsquared_error = 362121326.398\nsamples = 81\nvalue = 222692.148'),
#  Text(0.11623073385901868, 0.7386363636363636, 'X[0] <= -1.112\nsquared_error = 174069575.598\nsamples = 43\nvalue = 213187.535'),
#  Text(0.11595170052965921, 0.7159090909090909, 'X[1] <= 1975.0\nsquared_error = 164895719.951\nsamples = 36\nvalue = 212196.222'),
#  Text(0.11567266720029974, 0.6931818181818182, 'squared_error = 189893548.96\nsamples = 10\nvalue = 213538.8'),
#  Text(0.11623073385901868, 0.6931818181818182, 'X[1] <= 1976.5\nsquared_error = 154321251.053\nsamples = 26\nvalue = 211679.846'),
#  Text(0.11595170052965921, 0.6704545454545454, 'squared_error = 158923655.087\nsamples = 17\nvalue = 210686.824'),
#  Text(0.11650976718837815, 0.6704545454545454, 'squared_error = 140246913.58\nsamples = 9\nvalue = 213555.556'),
#  Text(0.11650976718837815, 0.7159090909090909, 'squared_error = 190204081.633\nsamples = 7\nvalue = 218285.714'),
#  Text(0.11860251715857417, 0.7386363636363636, 'X[38] <= 0.5\nsquared_error = 357017756.233\nsamples = 38\nvalue = 233447.368'),
#  Text(0.1179049338351755, 0.7159090909090909, 'X[1] <= 1984.0\nsquared_error = 235424636.488\nsamples = 27\nvalue = 241259.259'),
#  Text(0.11734686717645657, 0.6931818181818182, 'X[1] <= 1982.5\nsquared_error = 58062222.222\nsamples = 15\nvalue = 232933.333'),
#  Text(0.1170678338470971, 0.6704545454545454, 'X[0] <= -1.071\nsquared_error = 62331360.947\nsamples = 13\nvalue = 232230.769'),
#  Text(0.11678880051773763, 0.6477272727272727, 'squared_error = 66800000.0\nsamples = 10\nvalue = 233000.0'),
#  Text(0.11734686717645657, 0.6477272727272727, 'squared_error = 38888888.889\nsamples = 3\nvalue = 229666.667'),
#  Text(0.11762590050581603, 0.6704545454545454, 'squared_error = 6250000.0\nsamples = 2\nvalue = 237500.0'),
#  Text(0.11846300049389444, 0.6931818181818182, 'X[1] <= 1985.5\nsquared_error = 262162222.222\nsamples = 12\nvalue = 251666.667'),
#  Text(0.11818396716453497, 0.6704545454545454, 'X[41] <= 0.5\nsquared_error = 83368000.0\nsamples = 10\nvalue = 256400.0'),
#  Text(0.1179049338351755, 0.6477272727272727, 'X[0] <= -1.214\nsquared_error = 45425306.122\nsamples = 7\nvalue = 254457.143'),
#  Text(0.11762590050581603, 0.625, 'squared_error = 0.0\nsamples = 1\nvalue = 263000.0'),
#  Text(0.11818396716453497, 0.625, 'squared_error = 38805555.556\nsamples = 6\nvalue = 253033.333'),
#  Text(0.11846300049389444, 0.6477272727272727, 'squared_error = 142542222.222\nsamples = 3\nvalue = 260933.333'),
#  Text(0.1187420338232539, 0.6704545454545454, 'squared_error = 484000000.0\nsamples = 2\nvalue = 228000.0'),
#  Text(0.11930010048197286, 0.7159090909090909, 'X[1] <= 1984.5\nsquared_error = 138016528.926\nsamples = 11\nvalue = 214272.727'),
#  Text(0.11902106715261339, 0.6931818181818182, 'squared_error = 87500000.0\nsamples = 4\nvalue = 225000.0'),
#  Text(0.11957913381133232, 0.6931818181818182, 'X[0] <= -1.337\nsquared_error = 63551020.408\nsamples = 7\nvalue = 208142.857'),
#  Text(0.11930010048197286, 0.6704545454545454, 'squared_error = 75840000.0\nsamples = 5\nvalue = 206400.0'),
#  Text(0.1198581671406918, 0.6704545454545454, 'X[0] <= -1.112\nsquared_error = 6250000.0\nsamples = 2\nvalue = 212500.0'),
#  Text(0.11957913381133232, 0.6477272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 215000.0'),
#  Text(0.12013720047005126, 0.6477272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 210000.0'),
#  Text(0.12041623379941073, 0.7613636363636364, 'X[1] <= 1991.5\nsquared_error = 200694214.876\nsamples = 22\nvalue = 267818.182'),
#  Text(0.12013720047005126, 0.7386363636363636, 'squared_error = 86000000.0\nsamples = 5\nvalue = 287000.0'),
#  Text(0.1206952671287702, 0.7386363636363636, 'X[0] <= -1.173\nsquared_error = 94380622.837\nsamples = 17\nvalue = 262176.471'),
#  Text(0.12041623379941073, 0.7159090909090909, 'squared_error = 55840000.0\nsamples = 5\nvalue = 258600.0'),
#  Text(0.12097430045812967, 0.7159090909090909, 'X[45] <= 0.5\nsquared_error = 102888888.889\nsamples = 12\nvalue = 263666.667'),
#  Text(0.1206952671287702, 0.6931818181818182, 'X[1] <= 1993.5\nsquared_error = 108264462.81\nsamples = 11\nvalue = 263090.909'),
#  Text(0.12041623379941073, 0.6704545454545454, 'squared_error = 130839506.173\nsamples = 9\nvalue = 263222.222'),
#  Text(0.12097430045812967, 0.6704545454545454, 'squared_error = 6250000.0\nsamples = 2\nvalue = 262500.0'),
#  Text(0.12125333378748915, 0.6931818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 270000.0'),
#  Text(0.12278801709896622, 0.8068181818181818, 'X[38] <= 0.5\nsquared_error = 2515484622.222\nsamples = 30\nvalue = 372826.667'),
#  Text(0.12209043377556755, 0.7840909090909091, 'X[49] <= 0.5\nsquared_error = 699040532.544\nsamples = 26\nvalue = 389915.385'),
#  Text(0.12153236711684862, 0.7613636363636364, 'X[1] <= 1984.5\nsquared_error = 612000000.0\nsamples = 9\nvalue = 411333.333'),
#  Text(0.12125333378748915, 0.7386363636363636, 'squared_error = 417555555.556\nsamples = 3\nvalue = 409333.333'),
#  Text(0.12181140044620808, 0.7386363636363636, 'squared_error = 706222222.222\nsamples = 6\nvalue = 412333.333'),
#  Text(0.12264850043428649, 0.7613636363636364, 'X[1] <= 1987.0\nsquared_error = 373693564.014\nsamples = 17\nvalue = 378576.471'),
#  Text(0.12236946710492702, 0.7386363636363636, 'X[0] <= -1.235\nsquared_error = 186040000.0\nsamples = 10\nvalue = 369400.0'),
#  Text(0.12209043377556755, 0.7159090909090909, 'X[1] <= 1985.5\nsquared_error = 193358024.691\nsamples = 9\nvalue = 370555.556'),
#  Text(0.12181140044620808, 0.6931818181818182, 'squared_error = 100000000.0\nsamples = 2\nvalue = 380000.0'),
#  Text(0.12236946710492702, 0.6931818181818182, 'squared_error = 187265306.122\nsamples = 7\nvalue = 367857.143'),
#  Text(0.12264850043428649, 0.7159090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 359000.0'),
#  Text(0.12292753376364596, 0.7386363636363636, 'squared_error = 349621224.49\nsamples = 7\nvalue = 391685.714'),
#  Text(0.12348560042236491, 0.7840909090909091, 'X[0] <= -1.255\nsquared_error = 86187500.0\nsamples = 4\nvalue = 261750.0'),
#  Text(0.12320656709300544, 0.7613636363636364, 'squared_error = 110222222.222\nsamples = 3\nvalue = 260666.667'),
#  Text(0.12376463375172438, 0.7613636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 265000.0'),
#  Text(0.12707815453786808, 0.8295454545454546, 'X[0] <= -1.214\nsquared_error = 613477786.918\nsamples = 147\nvalue = 321774.612'),
#  Text(0.12536907539554132, 0.8068181818181818, 'X[0] <= -1.44\nsquared_error = 473458115.413\nsamples = 37\nvalue = 302883.784'),
#  Text(0.12460173373980278, 0.7840909090909091, 'X[1] <= 1984.0\nsquared_error = 596958677.686\nsamples = 11\nvalue = 284636.364'),
#  Text(0.12432270041044331, 0.7613636363636364, 'squared_error = 0.0\nsamples = 1\nvalue = 308000.0'),
#  Text(0.12488076706916225, 0.7613636363636364, 'squared_error = 596610000.0\nsamples = 10\nvalue = 282300.0'),
#  Text(0.12613641705127987, 0.7840909090909091, 'X[1] <= 1986.5\nsquared_error = 220737292.899\nsamples = 26\nvalue = 310603.846'),
#  Text(0.1254388337278812, 0.7613636363636364, 'X[0] <= -1.296\nsquared_error = 215349413.58\nsamples = 18\nvalue = 313094.444'),
#  Text(0.12488076706916225, 0.7386363636363636, 'X[1] <= 1985.5\nsquared_error = 355947755.102\nsamples = 7\nvalue = 318828.571'),
#  Text(0.12460173373980278, 0.7159090909090909, 'squared_error = 425366400.0\nsamples = 5\nvalue = 318960.0'),
#  Text(0.12515980039852173, 0.7159090909090909, 'squared_error = 182250000.0\nsamples = 2\nvalue = 318500.0'),
#  Text(0.12599690038660014, 0.7386363636363636, 'X[1] <= 1984.5\nsquared_error = 91638842.975\nsamples = 11\nvalue = 309445.455'),
#  Text(0.12571786705724067, 0.7159090909090909, 'squared_error = 28202222.222\nsamples = 3\nvalue = 315966.667'),
#  Text(0.1262759337159596, 0.7159090909090909, 'X[1] <= 1985.5\nsquared_error = 93500000.0\nsamples = 8\nvalue = 307000.0'),
#  Text(0.12599690038660014, 0.6931818181818182, 'squared_error = 101583333.333\nsamples = 6\nvalue = 305500.0'),
#  Text(0.12655496704531907, 0.6931818181818182, 'squared_error = 42250000.0\nsamples = 2\nvalue = 311500.0'),
#  Text(0.12683400037467854, 0.7613636363636364, 'X[45] <= 0.5\nsquared_error = 187500000.0\nsamples = 8\nvalue = 305000.0'),
#  Text(0.12655496704531907, 0.7386363636363636, 'squared_error = 238888888.889\nsamples = 3\nvalue = 296666.667'),
#  Text(0.127113033704038, 0.7386363636363636, 'X[1] <= 1987.5\nsquared_error = 90000000.0\nsamples = 5\nvalue = 310000.0'),
#  Text(0.12683400037467854, 0.7159090909090909, 'squared_error = 104687500.0\nsamples = 4\nvalue = 311250.0'),
#  Text(0.12739206703339748, 0.7159090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 305000.0'),
#  Text(0.12878723368019485, 0.8068181818181818, 'X[0] <= -1.173\nsquared_error = 500163739.869\nsamples = 110\nvalue = 328128.8'),
#  Text(0.12850820035083535, 0.7840909090909091, 'squared_error = 53555555.556\nsamples = 6\nvalue = 368333.333'),
#  Text(0.12906626700955431, 0.7840909090909091, 'X[1] <= 1984.5\nsquared_error = 427295446.29\nsamples = 104\nvalue = 325809.308'),
#  Text(0.12850820035083535, 0.7613636363636364, 'X[0] <= -0.968\nsquared_error = 423572637.735\nsamples = 57\nvalue = 330543.86'),
#  Text(0.12822916702147588, 0.7386363636363636, 'X[1] <= 1983.5\nsquared_error = 421923666.91\nsamples = 37\nvalue = 333810.811'),
#  Text(0.1279501336921164, 0.7159090909090909, 'squared_error = 131555555.556\nsamples = 3\nvalue = 324666.667'),
#  Text(0.12850820035083535, 0.7159090909090909, 'squared_error = 439515570.934\nsamples = 34\nvalue = 334617.647'),
#  Text(0.12878723368019485, 0.7386363636363636, 'squared_error = 370350000.0\nsamples = 20\nvalue = 324500.0'),
#  Text(0.12962433366827325, 0.7613636363636364, 'X[0] <= -1.132\nsquared_error = 371655546.539\nsamples = 47\nvalue = 320067.404'),
#  Text(0.12934530033891378, 0.7386363636363636, 'squared_error = 577760000.0\nsamples = 5\nvalue = 310700.0'),
#  Text(0.12990336699763272, 0.7386363636363636, 'X[1] <= 1985.5\nsquared_error = 335429482.531\nsamples = 42\nvalue = 321182.571'),
#  Text(0.12913602534189417, 0.7159090909090909, 'X[0] <= -0.968\nsquared_error = 398005540.166\nsamples = 19\nvalue = 324315.789'),
#  Text(0.1288569920125347, 0.6931818181818182, 'X[45] <= 0.5\nsquared_error = 250204081.633\nsamples = 7\nvalue = 321714.286'),
#  Text(0.12857795868317523, 0.6704545454545454, 'squared_error = 271333333.333\nsamples = 6\nvalue = 320000.0'),
#  Text(0.12913602534189417, 0.6704545454545454, 'squared_error = 0.0\nsamples = 1\nvalue = 332000.0'),
#  Text(0.12941505867125364, 0.6931818181818182, 'squared_error = 477972222.222\nsamples = 12\nvalue = 325833.333'),
#  Text(0.13067070865337124, 0.7159090909090909, 'X[1] <= 1986.5\nsquared_error = 268927124.628\nsamples = 23\nvalue = 318594.261'),
#  Text(0.12997312532997257, 0.6931818181818182, 'X[41] <= 0.5\nsquared_error = 185836734.694\nsamples = 7\nvalue = 312857.143'),
#  Text(0.1296940920006131, 0.6704545454545454, 'squared_error = 1000000.0\nsamples = 2\nvalue = 319000.0'),
#  Text(0.13025215865933204, 0.6704545454545454, 'squared_error = 238640000.0\nsamples = 5\nvalue = 310400.0'),
#  Text(0.13136829197676994, 0.6931818181818182, 'X[41] <= 0.5\nsquared_error = 284579020.938\nsamples = 16\nvalue = 321104.25'),
#  Text(0.13081022531805098, 0.6704545454545454, 'X[1] <= 1987.5\nsquared_error = 132250000.0\nsamples = 2\nvalue = 328500.0'),
#  Text(0.1305311919886915, 0.6477272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 317000.0'),
#  Text(0.13108925864741047, 0.6477272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 340000.0'),
#  Text(0.13192635863548888, 0.6704545454545454, 'X[1] <= 1987.5\nsquared_error = 297410167.918\nsamples = 14\nvalue = 320047.714'),
#  ...]

# %% [markdown]
# #### CP optimum

# %%
path = model.cost_complexity_pruning_path(X_train, Y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities
print(ccp_alphas, impurities)
# Out:
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 8.08386555e+08
#  2.18290293e+09 7.18806065e+09] [8.10650349e+08 8.10650349e+08 8.10650349e+08 ... 1.41982941e+10
#  1.63811971e+10 2.35692577e+10]

# %% [markdown]
# ### Random Forest

# %%
from sklearn import ensemble
model = ensemble.RandomForestRegressor(random_state=1)

# %%
model.fit(X_train,Y_train)
pred = model.predict(X_test)
print("RMSE for random forest:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for random forest: 40131.48387287037

# %% [markdown]
# ### Gradient Boosting

# %%
model = ensemble.GradientBoostingRegressor(random_state=1)

# %%
model.fit(X_train,Y_train)
pred = model.predict(X_test)
print("RMSE for gradient boosting:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for gradient boosting: 62325.73754141881

# %% [markdown]
# ### Neural Network

# %%
from sklearn import neural_network
model = neural_network.MLPRegressor(random_state=1)

# %%
model.fit(X_train,Y_train)
pred = model.predict(X_test)
print("RMSE for neural network:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for neural network: 151107.6835284498
# /Users/teresazhang/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ### Keras

# %%
import random
random.seed(1)

import numpy
numpy.random.seed(1)

import tensorflow as tf
tf.random.set_seed(1)

from keras.models import Sequential
from keras.layers import Dense,Dropout

# %%
model = Sequential()

# %%
model.add(Dense(37,input_dim=54,activation='relu'))
model.add(Dropout(0.1))

# %%
model.add(Dense(37,activation='relu'))
model.add(Dropout(0.1))

# %%
model.add(Dense(1,activation="linear"))

# %%
model.compile(loss="mse",optimizer="adam",metrics=["mse"])

# %%
b = 5
h = model.fit(X_train,Y_train,batch_size=b,epochs=100)
# Out:
# Epoch 1/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 43411734528.0000 - mse: 43411734528.0000
# Epoch 2/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 25170642944.0000 - mse: 25170642944.0000
# Epoch 3/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 24834492416.0000 - mse: 24834492416.0000
# Epoch 4/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 24995911680.0000 - mse: 24995911680.0000
# Epoch 5/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 24598968320.0000 - mse: 24598968320.0000
# Epoch 6/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 24562176000.0000 - mse: 24562176000.0000
# Epoch 7/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 23958732800.0000 - mse: 23958732800.0000
# Epoch 8/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 23440510976.0000 - mse: 23440510976.0000
# Epoch 9/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 23048263680.0000 - mse: 23048263680.0000
# Epoch 10/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 22149488640.0000 - mse: 22149488640.0000
# Epoch 11/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 21269946368.0000 - mse: 21269942272.0000
# Epoch 12/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 20082710528.0000 - mse: 20082710528.0000
# Epoch 13/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 18263054336.0000 - mse: 18263054336.0000
# Epoch 14/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 16227326976.0000 - mse: 16227326976.0000
# Epoch 15/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 14839465984.0000 - mse: 14839465984.0000
# Epoch 16/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 14096377856.0000 - mse: 14096378880.0000
# Epoch 17/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13954154496.0000 - mse: 13954154496.0000
# Epoch 18/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13517415424.0000 - mse: 13517415424.0000
# Epoch 19/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13452122112.0000 - mse: 13452122112.0000
# Epoch 20/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13353037824.0000 - mse: 13353037824.0000
# Epoch 21/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 12906597376.0000 - mse: 12906597376.0000
# Epoch 22/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 12786966528.0000 - mse: 12786966528.0000
# Epoch 23/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 12841737216.0000 - mse: 12841737216.0000
# Epoch 24/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 12464847872.0000 - mse: 12464845824.0000
# Epoch 25/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 12319411200.0000 - mse: 12319411200.0000
# Epoch 26/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 12164625408.0000 - mse: 12164625408.0000
# Epoch 27/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 11907670016.0000 - mse: 11907670016.0000
# Epoch 28/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 11781671936.0000 - mse: 11781671936.0000
# Epoch 29/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 11573168128.0000 - mse: 11573168128.0000
# Epoch 30/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 11278049280.0000 - mse: 11278049280.0000
# Epoch 31/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 11184624640.0000 - mse: 11184625664.0000
# Epoch 32/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10907783168.0000 - mse: 10907783168.0000
# Epoch 33/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10791332864.0000 - mse: 10791332864.0000
# Epoch 34/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10723338240.0000 - mse: 10723338240.0000
# Epoch 35/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10281263104.0000 - mse: 10281263104.0000
# Epoch 36/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10146169856.0000 - mse: 10146169856.0000
# Epoch 37/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9915310080.0000 - mse: 9915309056.0000
# Epoch 38/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9620999168.0000 - mse: 9620999168.0000
# Epoch 39/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9572029440.0000 - mse: 9572028416.0000
# Epoch 40/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9494824960.0000 - mse: 9494824960.0000
# Epoch 41/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9318493184.0000 - mse: 9318493184.0000
# Epoch 42/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9134294016.0000 - mse: 9134294016.0000
# Epoch 43/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8801078272.0000 - mse: 8801078272.0000
# Epoch 44/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8665376768.0000 - mse: 8665376768.0000
# Epoch 45/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8661698560.0000 - mse: 8661698560.0000
# Epoch 46/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8652198912.0000 - mse: 8652198912.0000
# Epoch 47/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8457714688.0000 - mse: 8457714688.0000
# Epoch 48/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8450753024.0000 - mse: 8450752512.0000
# Epoch 49/100
# 3331/3331 [==============================] - 5s 2ms/step - loss: 8263166976.0000 - mse: 8263166976.0000
# Epoch 50/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 8253963264.0000 - mse: 8253963776.0000
# Epoch 51/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8190090752.0000 - mse: 8190090752.0000
# Epoch 52/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8004569600.0000 - mse: 8004568576.0000
# Epoch 53/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7946830848.0000 - mse: 7946830848.0000
# Epoch 54/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7902474240.0000 - mse: 7902474240.0000
# Epoch 55/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7860854272.0000 - mse: 7860854272.0000
# Epoch 56/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7738377216.0000 - mse: 7738377216.0000
# Epoch 57/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7759825408.0000 - mse: 7759825408.0000
# Epoch 58/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7699136000.0000 - mse: 7699136000.0000
# Epoch 59/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7718654464.0000 - mse: 7718654464.0000
# Epoch 60/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7754238976.0000 - mse: 7754238976.0000
# Epoch 61/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7577485824.0000 - mse: 7577485824.0000
# Epoch 62/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7402897920.0000 - mse: 7402897920.0000
# Epoch 63/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7483566592.0000 - mse: 7483566592.0000
# Epoch 64/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7486324736.0000 - mse: 7486324736.0000
# Epoch 65/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7538632704.0000 - mse: 7538632704.0000
# Epoch 66/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7462072832.0000 - mse: 7462072832.0000
# Epoch 67/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7418286080.0000 - mse: 7418286080.0000
# Epoch 68/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7332729856.0000 - mse: 7332729856.0000
# Epoch 69/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7297856512.0000 - mse: 7297856512.0000
# Epoch 70/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7283713024.0000 - mse: 7283713024.0000
# Epoch 71/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7076850176.0000 - mse: 7076850176.0000
# Epoch 72/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7338189312.0000 - mse: 7338189312.0000
# Epoch 73/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7195363328.0000 - mse: 7195363328.0000
# Epoch 74/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7178150400.0000 - mse: 7178150400.0000
# Epoch 75/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7193881088.0000 - mse: 7193881088.0000
# Epoch 76/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7095204864.0000 - mse: 7095204864.0000
# Epoch 77/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7210835456.0000 - mse: 7210835456.0000
# Epoch 78/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7096812544.0000 - mse: 7096812544.0000
# Epoch 79/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7256771584.0000 - mse: 7256771584.0000
# Epoch 80/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7109705728.0000 - mse: 7109705728.0000
# Epoch 81/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7292701184.0000 - mse: 7292701184.0000
# Epoch 82/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7118756352.0000 - mse: 7118756352.0000
# Epoch 83/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7124427264.0000 - mse: 7124427264.0000
# Epoch 84/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6967156224.0000 - mse: 6967156224.0000
# Epoch 85/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7077442560.0000 - mse: 7077442560.0000
# Epoch 86/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7177068032.0000 - mse: 7177068032.0000
# Epoch 87/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7142271488.0000 - mse: 7142271488.0000
# Epoch 88/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7101309952.0000 - mse: 7101309952.0000
# Epoch 89/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7064393728.0000 - mse: 7064393728.0000
# Epoch 90/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7131229696.0000 - mse: 7131229696.0000
# Epoch 91/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 6968340992.0000 - mse: 6968340992.0000
# Epoch 92/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6973337600.0000 - mse: 6973337600.0000
# Epoch 93/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7087841280.0000 - mse: 7087841280.0000
# Epoch 94/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7065757184.0000 - mse: 7065757184.0000
# Epoch 95/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7000549376.0000 - mse: 7000549376.0000
# Epoch 96/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7097097216.0000 - mse: 7097097216.0000
# Epoch 97/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6940216832.0000 - mse: 6940216832.0000
# Epoch 98/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6891279360.0000 - mse: 6891279360.0000
# Epoch 99/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6789343744.0000 - mse: 6789343744.0000
# Epoch 100/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6839096320.0000 - mse: 6839096320.0000

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(h.history["mse"])
plt.title("MSE")
# Out:
# Text(0.5, 1.0, 'MSE')

# %%
plt.plot(h.history["loss"])
plt.title("Loss")
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
pred = model.predict(X_test)
print("RMSE for keras:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# 174/174 [==============================] - 0s 843us/step
# RMSE for keras: 70223.95412607536

# %% [markdown]
# #### Using different optimizer for Keras

# %%
model = Sequential()

# %%
model.add(Dense(37,input_dim=54,activation='relu'))
model.add(Dropout(0.1))

# %%
model.add(Dense(37,activation='relu'))
model.add(Dropout(0.1))

# %%
model.add(Dense(1,activation="linear"))

# %%
model.compile(loss="mse",optimizer="RMSprop",metrics=["mse"])

# %%
b = 5
h = model.fit(X_train,Y_train,batch_size=b,epochs=100)
# Out:
# Epoch 1/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 49133408256.0000 - mse: 49133408256.0000
# Epoch 2/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 25050343424.0000 - mse: 25050343424.0000
# Epoch 3/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 24726591488.0000 - mse: 24726591488.0000
# Epoch 4/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 24786726912.0000 - mse: 24786726912.0000
# Epoch 5/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 24286586880.0000 - mse: 24286586880.0000
# Epoch 6/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 24302082048.0000 - mse: 24302082048.0000
# Epoch 7/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 23636447232.0000 - mse: 23636447232.0000
# Epoch 8/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 23272570880.0000 - mse: 23272568832.0000
# Epoch 9/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 22775060480.0000 - mse: 22775060480.0000
# Epoch 10/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 21972514816.0000 - mse: 21972514816.0000
# Epoch 11/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 21324591104.0000 - mse: 21324591104.0000
# Epoch 12/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 20007079936.0000 - mse: 20007079936.0000
# Epoch 13/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 18398310400.0000 - mse: 18398310400.0000
# Epoch 14/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 16440604672.0000 - mse: 16440604672.0000
# Epoch 15/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 15051405312.0000 - mse: 15051403264.0000
# Epoch 16/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 14263631872.0000 - mse: 14263631872.0000
# Epoch 17/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 13840793600.0000 - mse: 13840793600.0000
# Epoch 18/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13814672384.0000 - mse: 13814671360.0000
# Epoch 19/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13664291840.0000 - mse: 13664292864.0000
# Epoch 20/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13565021184.0000 - mse: 13565021184.0000
# Epoch 21/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13334037504.0000 - mse: 13334037504.0000
# Epoch 22/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13038586880.0000 - mse: 13038586880.0000
# Epoch 23/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 13129998336.0000 - mse: 13129999360.0000
# Epoch 24/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 12806561792.0000 - mse: 12806562816.0000
# Epoch 25/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 12630044672.0000 - mse: 12630044672.0000
# Epoch 26/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 12496079872.0000 - mse: 12496079872.0000
# Epoch 27/100
# 3331/3331 [==============================] - 3s 979us/step - loss: 12168383488.0000 - mse: 12168383488.0000
# Epoch 28/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 12108568576.0000 - mse: 12108568576.0000
# Epoch 29/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 12080951296.0000 - mse: 12080951296.0000
# Epoch 30/100
# 3331/3331 [==============================] - 3s 979us/step - loss: 11740095488.0000 - mse: 11740095488.0000
# Epoch 31/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 11706219520.0000 - mse: 11706219520.0000
# Epoch 32/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 11410085888.0000 - mse: 11410085888.0000
# Epoch 33/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 11246869504.0000 - mse: 11246869504.0000
# Epoch 34/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 11112352768.0000 - mse: 11112352768.0000
# Epoch 35/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10968907776.0000 - mse: 10968907776.0000
# Epoch 36/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10688422912.0000 - mse: 10688422912.0000
# Epoch 37/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10628187136.0000 - mse: 10628187136.0000
# Epoch 38/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10243176448.0000 - mse: 10243176448.0000
# Epoch 39/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 10048568320.0000 - mse: 10048568320.0000
# Epoch 40/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9993704448.0000 - mse: 9993704448.0000
# Epoch 41/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9949432832.0000 - mse: 9949432832.0000
# Epoch 42/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9578209280.0000 - mse: 9578209280.0000
# Epoch 43/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9351598080.0000 - mse: 9351598080.0000
# Epoch 44/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9173736448.0000 - mse: 9173736448.0000
# Epoch 45/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 9143275520.0000 - mse: 9143275520.0000
# Epoch 46/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8996541440.0000 - mse: 8996541440.0000
# Epoch 47/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8890184704.0000 - mse: 8890184704.0000
# Epoch 48/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 8638473216.0000 - mse: 8638473216.0000
# Epoch 49/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 8508141056.0000 - mse: 8508141056.0000
# Epoch 50/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 8384866304.0000 - mse: 8384866304.0000
# Epoch 51/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8354365952.0000 - mse: 8354365952.0000
# Epoch 52/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8187732992.0000 - mse: 8187732992.0000
# Epoch 53/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 8032576000.0000 - mse: 8032576000.0000
# Epoch 54/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7845966848.0000 - mse: 7845966336.0000
# Epoch 55/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7707985920.0000 - mse: 7707985920.0000
# Epoch 56/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7726019584.0000 - mse: 7726019584.0000
# Epoch 57/100
# 3331/3331 [==============================] - 3s 988us/step - loss: 7777587712.0000 - mse: 7777587712.0000
# Epoch 58/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7619212288.0000 - mse: 7619212288.0000
# Epoch 59/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7645163520.0000 - mse: 7645162496.0000
# Epoch 60/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7560709632.0000 - mse: 7560709632.0000
# Epoch 61/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7455875584.0000 - mse: 7455875584.0000
# Epoch 62/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7348861952.0000 - mse: 7348861952.0000
# Epoch 63/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7372190720.0000 - mse: 7372190720.0000
# Epoch 64/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7371520512.0000 - mse: 7371520512.0000
# Epoch 65/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7432093696.0000 - mse: 7432093184.0000
# Epoch 66/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7275016192.0000 - mse: 7275015680.0000
# Epoch 67/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 7238086144.0000 - mse: 7238086144.0000
# Epoch 68/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7279089152.0000 - mse: 7279089152.0000
# Epoch 69/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7223334912.0000 - mse: 7223334912.0000
# Epoch 70/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7227465728.0000 - mse: 7227465728.0000
# Epoch 71/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7102050816.0000 - mse: 7102050816.0000
# Epoch 72/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 7256566272.0000 - mse: 7256565760.0000
# Epoch 73/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7183934976.0000 - mse: 7183934976.0000
# Epoch 74/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6992711168.0000 - mse: 6992711168.0000
# Epoch 75/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7124282880.0000 - mse: 7124283392.0000
# Epoch 76/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 6985334784.0000 - mse: 6985334784.0000
# Epoch 77/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7012997120.0000 - mse: 7012997120.0000
# Epoch 78/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6948995584.0000 - mse: 6948995584.0000
# Epoch 79/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 7086186496.0000 - mse: 7086186496.0000
# Epoch 80/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6897719296.0000 - mse: 6897719296.0000
# Epoch 81/100
# 3331/3331 [==============================] - 5s 2ms/step - loss: 6924821504.0000 - mse: 6924822016.0000
# Epoch 82/100
# 3331/3331 [==============================] - 5s 2ms/step - loss: 6916286464.0000 - mse: 6916286464.0000
# Epoch 83/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6963746816.0000 - mse: 6963746816.0000
# Epoch 84/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6843158016.0000 - mse: 6843158016.0000
# Epoch 85/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6934303744.0000 - mse: 6934303744.0000
# Epoch 86/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 6948226560.0000 - mse: 6948226560.0000
# Epoch 87/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6979413504.0000 - mse: 6979413504.0000
# Epoch 88/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6919666176.0000 - mse: 6919665664.0000
# Epoch 89/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6845582848.0000 - mse: 6845582336.0000
# Epoch 90/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6902431232.0000 - mse: 6902431232.0000
# Epoch 91/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6748503040.0000 - mse: 6748503040.0000
# Epoch 92/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6803515392.0000 - mse: 6803515392.0000
# Epoch 93/100
# 3331/3331 [==============================] - 5s 1ms/step - loss: 6832135680.0000 - mse: 6832135680.0000
# Epoch 94/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6843096064.0000 - mse: 6843096064.0000
# Epoch 95/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 6906220544.0000 - mse: 6906220544.0000
# Epoch 96/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 6799700992.0000 - mse: 6799700992.0000
# Epoch 97/100
# 3331/3331 [==============================] - 3s 974us/step - loss: 6707983360.0000 - mse: 6707983360.0000
# Epoch 98/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 6714231808.0000 - mse: 6714231808.0000
# Epoch 99/100
# 3331/3331 [==============================] - 3s 1ms/step - loss: 6675283456.0000 - mse: 6675283456.0000
# Epoch 100/100
# 3331/3331 [==============================] - 4s 1ms/step - loss: 6673762816.0000 - mse: 6673762816.0000

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(h.history["mse"])
plt.title("MSE")
# Out:
# Text(0.5, 1.0, 'MSE')

# %%
plt.plot(h.history["loss"])
plt.title("Loss")
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
pred = model.predict(X_test)
print("RMSE for keras:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# 174/174 [==============================] - 0s 951us/step
# RMSE for keras: 71512.49009808284

# %% [markdown]
# #### RMSE increased slightly suggesting that adam is still a better optimizer.

# %% [markdown]
# ## Improving accuracy

# %% [markdown]
# ### Feature selection (instead of the 5 variables chosen)

# %%
from sklearn.feature_selection import f_regression, SelectKBest

# %%
#i = 0
#j = 0
#for i in range(42909):
#    a = df.remaining_lease.str.extractall('(\d+)')[0].iloc[i]
#    if df.remaining_lease.str.extractall('(\d+)').index[i][0]!=df.remaining_lease.str.extractall('(\d+)').index[i+1][0]:
#        i += 1
#        b = df.remaining_lease.str.extractall('(\d+)')[0].iloc[i]
#    else:
#        b = 0
#    df['remaining_lease'][j] = a+b/12
#    j += 1
df['remaining_lease']=df.remaining_lease.str.extract('(\d+)')

# %%
df_dc = pd.get_dummies(df, columns=['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range', 'flat_model'])

# %%
X = df_dc.drop(columns="resale_price")
Y = df_dc["resale_price"]

# %%
f = SelectKBest(score_func=f_regression,k=10).fit(X,Y)

# %%
f = f.get_support()

# %%
f
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
X.columns[f]
# Out:
# Index(['floor_area_sqm', 'lease_commence_date', 'remaining_lease',
#        'flat_type_3 ROOM', 'flat_type_5 ROOM', 'flat_type_EXECUTIVE',
#        'flat_model_Apartment', 'flat_model_DBSS', 'flat_model_Maisonette',
#        'flat_model_New Generation'],
#       dtype='object')

# %% [markdown]
# #### Using floor_area_sqm, lease_commence_date, remaining_lease, flat_type, and flat_model as the new chosen variables

# %%
df_drop = df[["resale_price", "flat_type", "floor_area_sqm", "flat_model", "lease_commence_date", "remaining_lease"]]

# %%
df_dc = pd.get_dummies(df_drop, columns=['flat_type', 'flat_model'])

# %%
from scipy import stats

# %%
df_dc["floor_area_sqm"] = stats.zscore(df["floor_area_sqm"] )

# %%
X = df_dc.drop(columns=["resale_price"])
Y = df_dc["resale_price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=1)

# %% [markdown]
# ## Machine Learning using Feature Selection

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.metrics import mean_squared_error
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_test)
pred
# Out:
# array([430497.59574487, 354299.17499464, 427619.78205075, ...,
#        431093.76521684, 384819.19908702, 560622.86959945])

# %%
print("RMSE for linear regression:", mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for linear regression: 105358.28633884124

# %% [markdown]
# ### Neural Network

# %%
from sklearn import neural_network
model = neural_network.MLPRegressor(random_state=1)

# %%
model.fit(X_train,Y_train)
pred = model.predict(X_test)
print("RMSE for neural network:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for neural network: 147733.01598634326
# /Users/teresazhang/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# #### The RMSE for linear regression increased significantly and the RMSE for neural network decreased slightly, suggesting that the orginal five attributes/features used were better for linear regression but feature selection works better for neural network.

# %% [markdown]
# ## Machine Learning models that do not require feature selection

# %%
df_dc = pd.get_dummies(df, columns=['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range', 'flat_model'])

# %%
X = df_dc.drop(columns="resale_price")
Y = df_dc["resale_price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=1)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor(random_state=1)

# %%
model.fit(X_train,Y_train)
pred = model.predict(X_test)
print("RMSE for decision tree:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for decision tree: 44126.51580474205

# %% [markdown]
# ### Random Forest

# %%
from sklearn import ensemble
model = ensemble.RandomForestRegressor(random_state=1)

# %%
model.fit(X_train,Y_train)
pred = model.predict(X_test)
print("RMSE for random forest:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for random forest: 33798.87342042434

# %% [markdown]
# ### Gradient Boosting

# %%
model = ensemble.GradientBoostingRegressor(random_state=1)

# %%
model.fit(X_train,Y_train)
pred = model.predict(X_test)
print("RMSE for gradient boosting:",mean_squared_error(Y_test,pred)**0.5)
# Out:
# RMSE for gradient boosting: 60580.911362109255

# %% [markdown]
# #### Feature selection is not important for these machine learning models as they have their own internal feature selection. When using all the X variables, the time for training the model significantly increased. Both the RMSE for decision tree and random forest did not change much, while the RMSE for gradient boosting significantly increased.

# %% [markdown]
# ## Pros and Cons for each model

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# #### Pros
# Linear regression performs exceptionally well for linearly separable data. Easier to implement, interpret and efficient to train. It handles overfitting pretty well using dimensionally reduction techniques, regularization, and cross-validation.

# %% [markdown]
# #### Cons
# There is an assumption of linearity between dependent and independent variables, independence between attributes, normal distribution of the error, and constant standard deviation. It is often sensitive to outliers, prone to noise, overfitting, and multicollinearity.

# %% [markdown]
# #### How to overcome the weaknesses
# Can use different shape of regression, e.g. Quantile Regression. Since the errors for linear regression do not have a constant variance as shown by the Q-Q plot, it helps by separating the data using quantiles so the non-constant variance does not matter.
# Using MARS will help to counter the assumption of linearity between dependent and independent variables.
# Could use backward elimination with AIC to choose variables instead of feature selection.

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# #### Pros
# If there is a high non-linearity and complec relationship between dependent & independent variables, a tree model will outperform a classical regression method. To build a model which is easy to explain to people, a decision tree model will always do better than a linear model.
# Decision trees generate understandable rules, they are capable of handline both continuous and categorical variables and provide a clear indication of which fields are nost important for prediction or classification.

# %% [markdown]
# #### Cons
# When there are large number of features with less datasets, linear regressions may outperform decision trees. It is less appropriate for a continuous attribute. The process of growing a decision tree is computationally expensive. At each node, each candidate splitting field must be sorted before its split can be found. And there is a problem with overfitting.

# %% [markdown]
# #### How to overcome the weaknesses
# Prune the tree so that there is no overfitting. Use random forest or gradient boosting for better accuracy.

# %% [markdown]
# ### Random Forest

# %% [markdown]
# #### Pros
# Robust to outliers.
# Works well with non-linear data.
# Lower risk of overfitting.
# Runs efficiently on a large dataset.
# Better accuracy than other classification algorithms. Bootstrap Aggregation (Bagging) is a general procedure that can be used to reduce the variance for those algorithm that have high variance.

# %% [markdown]
# #### Cons
# Random forests are found to be biased while dealing with categorical variables. It is slow in training a model. It is not suitable for linear methods with a lot of sparse features.

# %% [markdown]
# #### How to overcome the weaknesses
# Use less variables (those that are not important) to make training faster

# %% [markdown]
# ### Gradient Boosting

# %% [markdown]
# Gradient boosting trees can be more accurate than random forests. Because we train them to correct each other’s errors, they’re capable of capturing complex patterns in the data. However, if the data are noisy, the boosted trees may overfit and start modeling the noise.

# %% [markdown]
# #### Pros
# Lots of flexibility - can optimize on different loss functions and provides several hyper parameter tuning options that make the function fit very flexible.
# No data pre-processing required - often works great with categorical and numerical values as is.
# Handles missing data - imputation not required.

# %% [markdown]
# #### Cons
# Gradient Boosting Models will continue improving to minimize all errors. This can overemphasize outliers and cause overfitting.
# Computationally expensive - often require many trees (>1000) which can be time and memory exhaustive.
# The high flexibility results in many parameters that interact and influence heavily the behavior of the approach (number of iterations, tree depth, regularization parameters, etc.). This requires a large grid search during tuning.
# Less interpretative in nature, although this is easily addressed with various tools.

# %% [markdown]
# #### How to overcome the weaknesses
# Use less variables (those that are not important) to make training faster

# %% [markdown]
# ### Neural Network

# %% [markdown]
# #### Pros
# Neural Network uses entropy instead of gini coefficient to compute errors, which mimics human nature. It results in very low predictive error (on trainset!). It can capture complex relationships by increasing number of hidden nodes and/or hidden layers. There is no need to specify a relationship between Y and Xs for neural networks. Neural networks are good to model with nonlinear data with large number of inputs; for example, images. It is reliable in an approach of tasks involving many features. It works by splitting the problem of classification into a layered network of simpler elements.
# Once trained, the predictions are pretty fast.
# Neural networks can be trained with any number of inputs and layers.

# %% [markdown]
# #### Cons
# Neural networks are black boxes, meaning we cannot know how much each independent variable is influencing the dependent variables.
# It is computationally very expensive and time consuming to train with traditional CPUs.
# Neural networks depend a lot on training data. This leads to the problem of over-fitting and generalization. The mode relies more on the training data and may be tuned to the data.

# %% [markdown]
# #### How to overcome the weaknesses
# Deep neural networks are prone to overfitting because they learn millions or billions of parameters while building the model. A model having this many parameters can overfit the training data because it has sufficient capacity to do so.
#
# The basic idea to deal with the problem of overfitting is to decrease the complexity of the model. To do so, we can make the network smaller by simply removing the layers or reducing the number of neurons, etc.

# %% [markdown]
# ### Importance of model to bank

# %% [markdown]
# Random Forest performed the best with the smallest RMSE of 40131.48387287037 even after various improvements made to the other models. The model can improve without eliminating features or doing feature selection as it has its own feature selection already, and having more data points can result in a more accurate model for random forest (even though the training time will take longer). The bank can plot out the tree to see which variables are more important, so they can put in more care into researching these variables when deciding the flat resale price.
